# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import itertools
from collections import Counter
from operator import itemgetter
from networkx.algorithms import community
from networkx.drawing.nx_agraph import graphviz_layout

# %%
df = pd.read_csv('data/hash_edges_100.csv')

# %%
# drops first row, which will be inserted as 'data' below
df.drop(df.index[0], inplace=True)

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
#row.values[0] = string
#row.values[1] = int
# splits up string into two separate columns (nodes, representing edges)

data = [['maga', 'stopthesteal', 1.0]]
edges_df = pd.DataFrame(data, columns = ['edge1', 'edge2', 'weight'])

for index, row in df.iterrows():
    weight = row.values[1] # holds weight as int for placement
    tup = row.values[0]
    tup = tup.replace("(", "")
    tup = tup.replace(")", "")
    tup = tup.replace("'", "")
    tup = tup.replace(",", "")
    tup = tup.split(' ')
    temp_data = [[tup[0], tup[1], weight]]
    temp_edges_df = pd.DataFrame(temp_data, columns = ['edge1', 'edge2', 'weight'])
    edges_df = edges_df.append(temp_edges_df, ignore_index=True)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
G = nx.MultiGraph()
G = nx.from_pandas_edgelist(edges_df, source='edge1', target='edge2', edge_attr=["weight"])

# %%
print(G.number_of_edges())
print(G.number_of_nodes())
# Out:
# 49
# 34

# %%
# creates dict of nodes
nodes = dict(G.nodes())

# %%
# converts to multigraph, with self-loops and parallel edges
hashG = nx.MultiGraph(G)

# %%
deg = dict(nx.degree(hashG))

# %%
deg
# Out:
# {'maga': 6,
#  'stopthesteal': 33,
#  'trump': 3,
#  'marchfortrump': 2,
#  'fightfortrump': 2,
#  'trumpwon': 5,
#  'trump2020': 2,
#  '世界をひっくり返そう': 2,
#  'wethepeople': 1,
#  'stopthecoup': 3,
#  '6-Jan': 1,
#  'fightback': 1,
#  'kag': 2,
#  'draintheswamp': 1,
#  'electionfraud': 1,
#  'speakupgop': 1,
#  'americafirst': 1,
#  'primaryrinos': 3,
#  'gop': 3,
#  'georgia': 1,
#  'traitortrump': 3,
#  'electionintegritymatters': 3,
#  'trumplieseverytimehespeaks': 3,
#  'trumpcorruption': 3,
#  'capitol': 1,
#  'voterfraud': 1,
#  'electionfraud2020': 3,
#  'washingtondc': 1,
#  'usa': 1,
#  'fightforamerica': 1,
#  'holdtheline': 1,
#  'saveamerica': 1,
#  'kraken': 1,
#  'america': 1}

# %%
isolates = nx.isolates(hashG)

# %%
hashG.remove_nodes_from(isolates)

# %%
isolates = nx.isolates(hashG)

# %%
sorted_degree = sorted(deg.items(), key=itemgetter(1), reverse=True)

# %%
print("Top 20 nodes by degree:")
for d in sorted_degree[:20]:
    print(d)
# Out:
# Top 20 nodes by degree:
# ('stopthesteal', 33)
# ('maga', 6)
# ('trumpwon', 5)
# ('trump', 3)
# ('stopthecoup', 3)
# ('primaryrinos', 3)
# ('gop', 3)
# ('traitortrump', 3)
# ('electionintegritymatters', 3)
# ('trumplieseverytimehespeaks', 3)
# ('trumpcorruption', 3)
# ('electionfraud2020', 3)
# ('marchfortrump', 2)
# ('fightfortrump', 2)
# ('trump2020', 2)
# ('世界をひっくり返そう', 2)
# ('kag', 2)
# ('wethepeople', 1)
# ('6-Jan', 1)
# ('fightback', 1)

# %%
# betweenness_dict = nx.betweenness_centrality(hashG) # Run betweenness centrality
# eigenvector_dict = nx.eigenvector_centrality(hashG) # Run eigenvector centrality

# %%
communities = community.greedy_modularity_communities(hashG)

# %%
# #creates a number value for each person based on community to which they belong

# modularity_dict = {} 
# for i,c in enumerate(communities): # Loop through the list of communities, keeping track of the number for the community
#     for name in c: # Loop through each person in a community
#         modularity_dict[name] = i # Create an entry in the dictionary for the person, where the value is which group they belong to.

# %%
for i,c in enumerate(communities): # Loop through the list of communities
    if len(c) > 5: # Filter out modularity classes with 2 or fewer nodes
        print('Class '+str(i)+':', list(c)) # Print out the classes and their members

# %%
# #how to get neighbors
# list(hashG.neighbors('wwg1wga'))

# %%
nx.degree_centrality(hashG)
# Out:
# {'maga': 0.18181818181818182,
#  'stopthesteal': 1.0,
#  'trump': 0.09090909090909091,
#  'marchfortrump': 0.06060606060606061,
#  'fightfortrump': 0.06060606060606061,
#  'trumpwon': 0.15151515151515152,
#  'trump2020': 0.06060606060606061,
#  '世界をひっくり返そう': 0.06060606060606061,
#  'wethepeople': 0.030303030303030304,
#  'stopthecoup': 0.09090909090909091,
#  '6-Jan': 0.030303030303030304,
#  'fightback': 0.030303030303030304,
#  'kag': 0.06060606060606061,
#  'draintheswamp': 0.030303030303030304,
#  'electionfraud': 0.030303030303030304,
#  'speakupgop': 0.030303030303030304,
#  'americafirst': 0.030303030303030304,
#  'primaryrinos': 0.09090909090909091,
#  'gop': 0.09090909090909091,
#  'georgia': 0.030303030303030304,
#  'traitortrump': 0.09090909090909091,
#  'electionintegritymatters': 0.09090909090909091,
#  'trumplieseverytimehespeaks': 0.09090909090909091,
#  'trumpcorruption': 0.09090909090909091,
#  'capitol': 0.030303030303030304,
#  'voterfraud': 0.030303030303030304,
#  'electionfraud2020': 0.09090909090909091,
#  'washingtondc': 0.030303030303030304,
#  'usa': 0.030303030303030304,
#  'fightforamerica': 0.030303030303030304,
#  'holdtheline': 0.030303030303030304,
#  'saveamerica': 0.030303030303030304,
#  'kraken': 0.030303030303030304,
#  'america': 0.030303030303030304}

# %%
len(list(nx.find_cliques(hashG)))
# Out:
# 25

# %%
# can you put the cliques into new graph and draw them?

gl = list(nx.find_cliques(hashG))
# nx.draw(G, with_labels=True)

# %%
# betCent = nx.betweenness_centrality(hashG, normalized=True, endpoints=True)

# %%
pos = nx.fruchterman_reingold_layout(hashG) #fruchterman_reingold 
plt.rcParams.update({'figure.figsize': (20, 15)})
nx.draw_networkx(
    hashG, 
    pos=pos, 
    node_size=1, 
    edge_color="#444444", 
    alpha=1, 
    with_labels=True)

# %%
plt.figure(figsize = (20,13))
nx.draw_networkx(hashG, pos=pos)
plt.savefig("images/hash100.png", format = "png", dpi = 300)
plt.show()

# %%
# hashG=nx.path_graph('stopthesteal')
#nx.write_gexf(hashG, "gexf/hash100.gexf")
