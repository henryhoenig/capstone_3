# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import itertools
from itertools import combinations
from collections import Counter
from operator import itemgetter
from networkx.algorithms import community
from networkx.drawing.nx_agraph import graphviz_layout

# %%
df = pd.read_csv('data/weighted_edges100.csv')

# %%
# Dropping nan values in first two rows
#df.drop(df.index[0], inplace=True)

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df.head(3)
# Out:
#                        edges   weights
# 0   ('maga', 'stopthesteal')  1.000000
# 1   ('stopthesteal', 'maga')  0.644009
# 2  ('trump', 'stopthesteal')  0.509217

# %%
#row.values[0] = string
#row.values[1] = int
# splits up string into two separate columns (nodes, representing edges)

data = [['americafirst', 'auditallvotes', 949]]
edges_df = pd.DataFrame(data, columns = ['edge1', 'edge2', 'weight'])

for index, row in df.iterrows():
    weight = row.values[1] # holds weight as int for placement
    tup = row.values[0]
    tup = tup.replace("(", "")
    tup = tup.replace(")", "")
    tup = tup.replace("'", "")
    tup = tup.replace(",", "")
    tup = tup.split(' ')
    temp_data = [[tup[0], tup[1], weight]]
    temp_edges_df = pd.DataFrame(temp_data, columns = ['edge1', 'edge2', 'weight'])
    edges_df = edges_df.append(temp_edges_df, ignore_index=True)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
G = nx.MultiGraph()
G = nx.from_pandas_edgelist(edges_df, source='edge1', target='edge2', edge_attr=["weight"])

# %%
print(G.number_of_edges())
print(G.number_of_nodes())
# Out:
# 50
# 35

# %%
# creates dict of nodes
nodes = dict(G.nodes())

# %%
# converts to multigraph, with self-loops and parallel edges
hashG = nx.MultiGraph(G)

# %%
deg = dict(nx.degree(hashG))

# %%
deg
# Out:
# {'americafirst': 2,
#  'auditallvotes': 1,
#  'maga': 6,
#  'stopthesteal': 33,
#  'trump': 3,
#  'marchfortrump': 2,
#  'fightfortrump': 2,
#  'trumpwon': 5,
#  'trump2020': 2,
#  '世界をひっくり返そう': 2,
#  'wethepeople': 1,
#  'stopthecoup': 3,
#  'fightback': 1,
#  'kag': 2,
#  'draintheswamp': 1,
#  'electionfraud': 1,
#  'jan6': 1,
#  'speakupgop': 1,
#  'primaryrinos': 3,
#  'gop': 3,
#  'georgia': 1,
#  'traitortrump': 3,
#  'electionintegritymatters': 3,
#  'trumplieseverytimehespeaks': 3,
#  'trumpcorruption': 3,
#  'capitol': 1,
#  'voterfraud': 1,
#  'washingtondc': 1,
#  'electionfraud2020': 3,
#  'usa': 1,
#  'fightforamerica': 1,
#  'holdtheline': 1,
#  'saveamerica': 1,
#  'kraken': 1,
#  'america': 1}

# %%
isolates = nx.isolates(hashG)

# %%
hashG.remove_nodes_from(isolates)

# %%
isolates = nx.isolates(hashG)

# %%
sorted_degree = sorted(deg.items(), key=itemgetter(1), reverse=True)

# %%
print("Top 20 nodes by degree:")
for d in sorted_degree[:20]:
    print(d)
# Out:
# Top 20 nodes by degree:
# ('stopthesteal', 33)
# ('maga', 6)
# ('trumpwon', 5)
# ('trump', 3)
# ('stopthecoup', 3)
# ('primaryrinos', 3)
# ('gop', 3)
# ('traitortrump', 3)
# ('electionintegritymatters', 3)
# ('trumplieseverytimehespeaks', 3)
# ('trumpcorruption', 3)
# ('electionfraud2020', 3)
# ('americafirst', 2)
# ('marchfortrump', 2)
# ('fightfortrump', 2)
# ('trump2020', 2)
# ('世界をひっくり返そう', 2)
# ('kag', 2)
# ('auditallvotes', 1)
# ('wethepeople', 1)

# %%
#betweenness_dict = nx.betweenness_centrality(hashG) # Run betweenness centrality
#eigenvector_dict = nx.eigenvector_centrality(hashG) # Run eigenvector centrality

# %%
communities = community.greedy_modularity_communities(hashG)

# %%
len(communities)
# Out:
# 1

# %%
# #creates a number value for each person based on community to which they belong

# modularity_dict = {} 
# for i,c in enumerate(communities): # Loop through the list of communities, keeping track of the number for the community
#     for name in c: # Loop through each person in a community
#         modularity_dict[name] = i # Create an entry in the dictionary for the person, where the value is which group they belong to.

# %%
for i,c in enumerate(communities): # Loop through the list of communities
    if len(c) > 5: # Filter out modularity classes with 2 or fewer nodes
        print('Class '+str(i)+':', list(c)) # Print out the classes and their members
# Out:
# Class 0: ['voterfraud', 'marchfortrump', 'maga', 'usa', 'traitortrump', 'draintheswamp', 'stopthecoup', 'trumplieseverytimehespeaks', 'electionfraud2020', 'trumpwon', 'auditallvotes', 'washingtondc', 'jan6', 'speakupgop', 'electionintegritymatters', 'fightfortrump', 'saveamerica', 'trump', 'stopthesteal', 'fightforamerica', 'america', 'primaryrinos', 'georgia', '世界をひっくり返そう', 'kag', 'americafirst', 'holdtheline', 'capitol', 'trump2020', 'wethepeople', 'trumpcorruption', 'electionfraud', 'fightback', 'kraken', 'gop']

# %%
# #how to get neighbors
# list(hashG.neighbors('wwg1wga'))

# %%
nx.degree_centrality(hashG)
# Out:
# {'americafirst': 0.058823529411764705,
#  'auditallvotes': 0.029411764705882353,
#  'maga': 0.1764705882352941,
#  'stopthesteal': 0.9705882352941176,
#  'trump': 0.08823529411764705,
#  'marchfortrump': 0.058823529411764705,
#  'fightfortrump': 0.058823529411764705,
#  'trumpwon': 0.14705882352941177,
#  'trump2020': 0.058823529411764705,
#  '世界をひっくり返そう': 0.058823529411764705,
#  'wethepeople': 0.029411764705882353,
#  'stopthecoup': 0.08823529411764705,
#  'fightback': 0.029411764705882353,
#  'kag': 0.058823529411764705,
#  'draintheswamp': 0.029411764705882353,
#  'electionfraud': 0.029411764705882353,
#  'jan6': 0.029411764705882353,
#  'speakupgop': 0.029411764705882353,
#  'primaryrinos': 0.08823529411764705,
#  'gop': 0.08823529411764705,
#  'georgia': 0.029411764705882353,
#  'traitortrump': 0.08823529411764705,
#  'electionintegritymatters': 0.08823529411764705,
#  'trumplieseverytimehespeaks': 0.08823529411764705,
#  'trumpcorruption': 0.08823529411764705,
#  'capitol': 0.029411764705882353,
#  'voterfraud': 0.029411764705882353,
#  'washingtondc': 0.029411764705882353,
#  'electionfraud2020': 0.08823529411764705,
#  'usa': 0.029411764705882353,
#  'fightforamerica': 0.029411764705882353,
#  'holdtheline': 0.029411764705882353,
#  'saveamerica': 0.029411764705882353,
#  'kraken': 0.029411764705882353,
#  'america': 0.029411764705882353}

# %%
len(list(nx.find_cliques(hashG)))
# Out:
# 26

# %%
# can you put the cliques into new graph and draw them?

gl = list(nx.find_cliques(hashG))
# nx.draw(G, with_labels=True)

# %%
gl
# Out:
# [['auditallvotes', 'americafirst'],
#  ['stopthesteal', 'voterfraud'],
#  ['stopthesteal', 'marchfortrump', '世界をひっくり返そう'],
#  ['stopthesteal', 'fightback'],
#  ['stopthesteal', 'maga', 'kag'],
#  ['stopthesteal', 'maga', 'fightfortrump'],
#  ['stopthesteal', 'maga', 'trump', 'gop'],
#  ['stopthesteal', 'maga', 'trump2020'],
#  ['stopthesteal', 'usa'],
#  ['stopthesteal',
#   'traitortrump',
#   'trumplieseverytimehespeaks',
#   'trumpcorruption'],
#  ['stopthesteal', 'draintheswamp'],
#  ['stopthesteal', 'stopthecoup', 'trumpwon', 'primaryrinos'],
#  ['stopthesteal', 'electionfraud2020', 'trumpwon', 'electionintegritymatters'],
#  ['stopthesteal', 'washingtondc'],
#  ['stopthesteal', 'jan6'],
#  ['stopthesteal', 'speakupgop'],
#  ['stopthesteal', 'saveamerica'],
#  ['stopthesteal', 'fightforamerica'],
#  ['stopthesteal', 'america'],
#  ['stopthesteal', 'georgia'],
#  ['stopthesteal', 'americafirst'],
#  ['stopthesteal', 'holdtheline'],
#  ['stopthesteal', 'capitol'],
#  ['stopthesteal', 'wethepeople'],
#  ['stopthesteal', 'electionfraud'],
#  ['stopthesteal', 'kraken']]

# %%
# # this seems important to drawing 
# betCent = nx.betweenness_centrality(hashG, normalized=True, endpoints=True)

# %%
pos = nx.fruchterman_reingold_layout(hashG) #fruchterman_reingold 
plt.rcParams.update({'figure.figsize': (20, 15)})
nx.draw_networkx(
    hashG, 
    pos=pos, 
    node_size=1, 
    edge_color="#444444", 
    alpha=1, 
    with_labels=False)

# %%
plt.figure(figsize = (20,13))
nx.draw_networkx(hashG, pos=pos)
plt.savefig("images/hash100.png", format = "png", dpi = 300)
plt.show()

# %%
# hashG=nx.path_graph('stopthesteal')
nx.write_gexf(hashG, "gexf/hash100.gexf")
