# %%
# !pip install gensim
# Out:
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'
# Requirement already satisfied: gensim in /home/ubuntu/anaconda3/envs/pytorch_latest_p37/lib/python3.7/site-packages (4.0.1)
# Requirement already satisfied: smart-open>=1.8.1 in /home/ubuntu/anaconda3/envs/pytorch_latest_p37/lib/python3.7/site-packages (from gensim) (3.0.0)
# Requirement already satisfied: scipy>=0.18.1 in /home/ubuntu/anaconda3/envs/pytorch_latest_p37/lib/python3.7/site-packages (from gensim) (1.6.1)
# Requirement already satisfied: numpy>=1.11.3 in /home/ubuntu/anaconda3/envs/pytorch_latest_p37/lib/python3.7/site-packages (from gensim) (1.19.2)
# Requirement already satisfied: requests in /home/ubuntu/anaconda3/envs/pytorch_latest_p37/lib/python3.7/site-packages (from smart-open>=1.8.1->gensim) (2.25.1)
# Requirement already satisfied: idna<3,>=2.5 in /home/ubuntu/anaconda3/envs/pytorch_latest_p37/lib/python3.7/site-packages (from requests->smart-open>=1.8.1->gensim) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ubuntu/anaconda3/envs/pytorch_latest_p37/lib/python3.7/site-packages (from requests->smart-open>=1.8.1->gensim) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ubuntu/anaconda3/envs/pytorch_latest_p37/lib/python3.7/site-packages (from requests->smart-open>=1.8.1->gensim) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in /home/ubuntu/anaconda3/envs/pytorch_latest_p37/lib/python3.7/site-packages (from requests->smart-open>=1.8.1->gensim) (4.0.0)

# %%
# !pip install pyLDAvis
# Out:
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'
# Requirement already satisfied: pyLDAvis in /home/ubuntu/anaconda3/envs/pytorch_latest_p37/lib/python3.7/site-packages (3.2.2)
# Requirement already satisfied: wheel>=0.23.0 in /home/ubuntu/anaconda3/envs/pytorch_latest_p37/lib/python3.7/site-packages (from pyLDAvis) (0.36.2)
# Requirement already satisfied: joblib>=0.8.4 in /home/ubuntu/anaconda3/envs/pytorch_latest_p37/lib/python3.7/site-packages (from pyLDAvis) (1.0.1)
# Requirement already satisfied: jinja2>=2.7.2 in /home/ubuntu/anaconda3/envs/pytorch_latest_p37/lib/python3.7/site-packages (from pyLDAvis) (2.11.3)
# Requirement already satisfied: scipy>=0.18.0 in /home/ubuntu/anaconda3/envs/pytorch_latest_p37/lib/python3.7/site-packages (from pyLDAvis) (1.6.1)
# Requirement already satisfied: funcy in /home/ubuntu/anaconda3/envs/pytorch_latest_p37/lib/python3.7/site-packages (from pyLDAvis) (1.15)
# Requirement already satisfied: numpy>=1.9.2 in /home/ubuntu/anaconda3/envs/pytorch_latest_p37/lib/python3.7/site-packages (from pyLDAvis) (1.19.2)
# Requirement already satisfied: numexpr in /home/ubuntu/anaconda3/envs/pytorch_latest_p37/lib/python3.7/site-packages (from pyLDAvis) (2.7.3)
# Requirement already satisfied: pandas>=0.17.0 in /home/ubuntu/anaconda3/envs/pytorch_latest_p37/lib/python3.7/site-packages (from pyLDAvis) (1.2.2)
# Requirement already satisfied: future in /home/ubuntu/anaconda3/envs/pytorch_latest_p37/lib/python3.7/site-packages (from pyLDAvis) (0.18.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/ubuntu/anaconda3/envs/pytorch_latest_p37/lib/python3.7/site-packages (from jinja2>=2.7.2->pyLDAvis) (1.1.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/ubuntu/anaconda3/envs/pytorch_latest_p37/lib/python3.7/site-packages (from pandas>=0.17.0->pyLDAvis) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /home/ubuntu/anaconda3/envs/pytorch_latest_p37/lib/python3.7/site-packages (from pandas>=0.17.0->pyLDAvis) (2021.1)
# Requirement already satisfied: six>=1.5 in /home/ubuntu/anaconda3/envs/pytorch_latest_p37/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas>=0.17.0->pyLDAvis) (1.15.0)

# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import NMF
from sklearn.feature_extraction.text import TfidfVectorizer
from gensim.models.coherencemodel import CoherenceModel
from gensim.corpora.dictionary import Dictionary
from gensim.models.nmf import Nmf
from collections import Counter
from operator import itemgetter
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')
import sklearn

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)

# %% [markdown]
# #### Load data

# %%
df = pd.read_csv('data/tweet_text.csv')

# %%
df.head()
# Out:
#                                                 text
# 0  jeremynewberger marklevinshow petehegseth we d...
# 1  hawleymo simonschuster a lot of courts are goi...
# 2  frznsoonrmn missilmom wow  i wish this video w...
# 3  wynk  will uniter president joe biden apologiz...
# 4  kittentalker usafreedom2020 stopthesteal godje...

# %%
df_short = df[0:5]

# %%
columnSeriesObj = df_short['text']
tweets = columnSeriesObj

# %%
master_list = []
for i in tweets:
    words = i.split()
    text = [re.sub('[0-9]+', '', word) for word in words]
    print(words)
    print(type(i))
    

#     table = str.maketrans('', '', string.punctuation)
#     i = [w.translate(table) for w in words]
#     i = " ".join(i)
#     i = i.lower()
#     i = re.sub(r'[^a-zA-Z0-9_\s]+', '', i)
#     master_list.append(i)





# text = casual_tokenizer(text)

# text = [re.sub('[0-9]+', '', each) for each in text]
# text = [expandContractions(each, c_re=c_re) for each in text]
# text = [SnowballStemmer('english').stem(each) for each in text]
# text = [w for w in text if w not in punc]
# text = [w for w in text if w not in stop_words]
# text = [each for each in text if len(each) > 1]
# text = [each for each in text if ' ' not in each]
# Out:
# ['jeremynewberger', 'marklevinshow', 'petehegseth', 'we', 'do', 'care', 'where', 'he', 'goes', 'who', 'are', 'you', 'againstopthesteal']
# <class 'str'>
# ['hawleymo', 'simonschuster', 'a', 'lot', 'of', 'courts', 'are', 'going', 'to', 'see', 'the', 'false', 'claims', 'of', 'voter', 'fraud', 'and', 'stopthesteal', 'rhetoric', 'you', 'deliberately', 'played', 'into', 'as', 'yelling', 'fire', 'into', 'a', 'crowded', 'theater', 'even', 'in', 'your', 'statement', 'you', 'use', 'the', 'word', 'fight', 'you', 'incited', 'this', 'mob', 'resign']
# <class 'str'>
# ['frznsoonrmn', 'missilmom', 'wow', 'i', 'wish', 'this', 'video', 'would', 'get', 'on', 'tv', 'i', 'have', 'always', 'loved', 'our', 'great', 'president', 'americafirst', 'stopthesteal', 'auditallvotes']
# <class 'str'>
# ['wynk', 'will', 'uniter', 'president', 'joe', 'biden', 'apologize', 'for', 'what', 'hes', 'said', 'and', 'done', 'power', 'vs', 'we', 'the', 'people', 'now', 'what', 'plus', 'the', 'pledge', 'eagleedmartin', 'periscope', 'proamericareport', 'joebiden', 'stopthesteal', 'httpstcoobiys6gfzt']
# <class 'str'>
# ['kittentalker', 'usafreedom2020', 'stopthesteal', 'godjesushs', 'nrsc', 'cointuckeywind1', 'matthew4trump', 'reallouiehuey', 'nickadamsinusa', 'michaelberrysho', 'llinwood', 'marklutchman', 'wdunlap', 'johnnyrwhitsett', 'thebradfordfile', 'technofog', 'freemont']
# <class 'str'>

# %%
data = pd.read_csv('data/tweet_text.csv', error_bad_lines=False)
data_text = data[['text']]
data_text['index'] = data_text.index
documents = data_text

# %% [markdown]
# #### Pre-process data

# %%
def lemmatize_stemming(text):
    return stemmer.stem(WordNetLemmatizer().lemmatize(text, pos='v'))

def preprocess(text):
    result = []
    for token in gensim.utils.simple_preprocess(text):
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 3:
            result.append(lemmatize_stemming(token))
    return result

# %%
stemmer = SnowballStemmer('english')
processed_docs = documents['text'].map(preprocess)

# %% [markdown]
# #### Bag of Words

# %%
#create dictionary
id2word = gensim.corpora.Dictionary(processed_docs)

#create corpus
texts = processed_docs

#Term Document Frequency
bow_corpus = [id2word.doc2bow(text) for text in texts]

# %%
# Human readable format of corpus (term-frequency)
[[(id2word[id], freq) for id, freq in cp] for cp in bow_corpus]
# Out:
# [[('care', 1),
#   ('go', 1),
#   ('jeremynewberg', 1),
#   ('marklevinshow', 1),
#   ('petehegseth', 1)],
#  [('go', 1),
#   ('claim', 1),
#   ('court', 1),
#   ('crowd', 1),
#   ('deliber', 1),
#   ('fals', 1),
#   ('fight', 1),
#   ('fraud', 1),
#   ('hawleymo', 1),
#   ('incit', 1),
#   ('play', 1),
#   ('resign', 1),
#   ('rhetor', 1),
#   ('simonschust', 1),
#   ('statement', 1),
#   ('stopthest', 1),
#   ('theater', 1),
#   ('voter', 1),
#   ('word', 1),
#   ('yell', 1)],
#  [('stopthest', 1),
#   ('americafirst', 1),
#   ('auditallvot', 1),
#   ('frznsoonrmn', 1),
#   ('great', 1),
#   ('love', 1),
#   ('missilmom', 1),
#   ('presid', 1),
#   ('video', 1),
#   ('wish', 1)],
#  [('stopthest', 1),
#   ('presid', 1),
#   ('apolog', 1),
#   ('biden', 1),
#   ('eagleedmartin', 1),
#   ('gfzt', 1),
#   ('httpstcoobiy', 1),
#   ('joebiden', 1),
#   ('peopl', 1),
#   ('periscop', 1),
#   ('pledg', 1),
#   ('plus', 1),
#   ('power', 1),
#   ('say', 1),
#   ('unit', 1),
#   ('wynk', 1)],
#  [('stopthest', 1),
#   ('cointuckeywind', 1),
#   ('freemont', 1),
#   ('godjesush', 1),
#   ('johnnyrwhitsett', 1),
#   ('kittentalk', 1),
#   ('llinwood', 1),
#   ('marklutchman', 1),
#   ('matthew', 1),
#   ('michaelberrysho', 1),
#   ('nickadamsinusa', 1),
#   ('nrsc', 1),
#   ('reallouiehuey', 1),
#   ('technofog', 1),
#   ('thebradfordfil', 1),
#   ('trump', 1),
#   ('usafreedom', 1),
#   ('wdunlap', 1)],
#  [('stopthest', 1),
#   ('peopl', 1),
#   ('acquir', 1),
#   ('awak', 1),
#   ('casual', 1),
#   ('ladi', 1),
#   ('look', 1),
#   ('maga', 1),
#   ('manufactur', 1),
#   ('photo', 1),
#   ('product', 1),
#   ('scaramucci', 1),
#   ('stroll', 1),
#   ('wethepeopl', 1),
#   ('wherehow', 1)],
#  [('stopthest', 1),
#   ('peopl', 1),
#   ('avoid', 1),
#   ('bag', 1),
#   ('bring', 1),
#   ('encourag', 1),
#   ('escal', 1),
#   ('event', 1),
#   ('founder', 1),
#   ('mask', 1),
#   ('movement', 1),
#   ('sleep', 1),
#   ('tent', 1),
#   ('wear', 1),
#   ('week', 1),
#   ('write', 1)],
#  [('stopthest', 1),
#   ('maga', 1),
#   ('movement', 1),
#   ('countri', 1),
#   ('creep', 1),
#   ('damn', 1),
#   ('httpstcogivh', 1),
#   ('mynrj', 1),
#   ('orgin', 1),
#   ('rapist', 1),
#   ('steal', 2),
#   ('stop', 1),
#   ('stopthesteai', 2)],
#  [('stopthest', 1),
#   ('antifa', 1),
#   ('holdaccount', 1),
#   ('httpstcosb', 1),
#   ('lockyhemup', 1),
#   ('nxqu', 1),
#   ('prayforamerica', 1),
#   ('prayfortrump', 1),
#   ('saveamerica', 1)],
#  [('stopthest', 1),
#   ('andrear', 1),
#   ('donwinslow', 1),
#   ('drcraigmalkin', 1),
#   ('dremilyportermd', 1),
#   ('drjudyston', 1),
#   ('funder', 1),
#   ('johnmtalmadgemd', 1),
#   ('justinamash', 1),
#   ('justinfrankmd', 1),
#   ('meidastouch', 1),
#   ('nickcarmodi', 1),
#   ('projectlincoln', 1),
#   ('radiofreetom', 1),
#   ('sethn', 1),
#   ('startthetri', 1),
#   ('walshfreedom', 1),
#   ('yourauntemma', 1)],
#  [('hawleymo', 1),
#   ('stopthest', 1),
#   ('crap', 1),
#   ('mikecrapo', 1),
#   ('patriot', 1),
#   ('tedcruz', 1),
#   ('traitor', 1)],
#  [('stopthest', 1),
#   ('trump', 1),
#   ('maga', 1),
#   ('wethepeopl', 1),
#   ('digitalsoldi', 1),
#   ('fightback', 1),
#   ('fightforamerica', 1),
#   ('fightforfreedom', 1),
#   ('fourmoreyear', 1),
#   ('fullaudit', 1),
#   ('holdthelin', 1),
#   ('itsnotov', 1),
#   ('kraken', 1),
#   ('potus', 1),
#   ('qarmi', 1)],
#  [('stopthest', 1),
#   ('coupattempt', 1),
#   ('prevent', 1),
#   ('run', 1),
#   ('that', 1)],
#  [('stopthest', 1),
#   ('fightfortrump', 1),
#   ('httpstco', 1),
#   ('stopthecoup', 1),
#   ('uepcdrin', 1)],
#  [('stopthest', 1),
#   ('voter', 2),
#   ('say', 1),
#   ('trump', 2),
#   ('baier', 1),
#   ('bret', 1),
#   ('camp', 1),
#   ('dont', 1),
#   ('elect', 1),
#   ('evid', 1),
#   ('fantasi', 1),
#   ('fellow', 1),
#   ('httpstcodintc', 1),
#   ('know', 1),
#   ('mountain', 1),
#   ('piss', 1),
#   ('theft', 1),
#   ('trumpwon', 1)],
#  [('stopthest', 1),
#   ('say', 1),
#   ('advoc', 1),
#   ('amend', 1),
#   ('communist', 2),
#   ('dbongino', 1),
#   ('exact', 1),
#   ('violat', 1),
#   ('willricci', 1),
#   ('your', 1)],
#  [('stopthest', 1), ('maga', 1), ('draintheswamp', 1)],
#  [('stopthest', 1), ('antifa', 1), ('httpstcomozq', 1)],
#  [('crowd', 1),
#   ('stopthest', 1),
#   ('steal', 1),
#   ('build', 1),
#   ('didnt', 1),
#   ('dummi', 1),
#   ('justwilliam', 1),
#   ('pissofftrumpkin', 1),
#   ('piti', 1),
#   ('polic', 1),
#   ('stand', 1),
#   ('steelergirl', 1),
#   ('sure', 1),
#   ('tearga', 1),
#   ('ulmeda', 1)],
#  [('stopthest', 1), ('stopthesteai', 1)],
#  [('stopthest', 1), ('exact', 1), ('donnawr', 1), ('right', 1), ('sum', 1)],
#  [('fraud', 1),
#   ('stopthest', 1),
#   ('elect', 1),
#   ('stand', 2),
#   ('thank', 1),
#   ('truth', 1)],
#  [('go', 1),
#   ('stopthest', 1),
#   ('say', 1),
#   ('maga', 2),
#   ('know', 1),
#   ('amen', 2),
#   ('awoman', 2),
#   ('crazi', 1),
#   ('doesnt', 1),
#   ('ignor', 2),
#   ('mean', 3),
#   ('pray', 1),
#   ('repcleav', 1),
#   ('show', 1),
#   ('understand', 1)],
#  [('stopthest', 1), ('trump', 1), ('fightfortrump', 1), ('presidenttrump', 1)],
#  [('fraud', 1), ('stopthest', 1), ('stand', 2), ('thank', 1), ('truth', 1)],
#  [('go', 1),
#   ('stopthest', 1),
#   ('great', 1),
#   ('countri', 1),
#   ('arrest', 1),
#   ('citizen', 1),
#   ('count', 1),
#   ('dcpolicedept', 1),
#   ('debacl', 1),
#   ('dhsgov', 1),
#   ('earlier', 1),
#   ('fbiwfo', 1),
#   ('help', 1),
#   ('increas', 1),
#   ('justic', 1),
#   ('save', 1),
#   ('today', 1),
#   ('yesterday', 1)],
#  [('stopthest', 1),
#   ('polic', 1),
#   ('leav', 1),
#   ('like', 1),
#   ('shoot', 1),
#   ('sudden', 1),
#   ('tabl', 1),
#   ('trumpsupport', 1),
#   ('turn', 1),
#   ('unarm', 1)],
#  [('stopthest', 1),
#   ('dont', 1),
#   ('advoc', 1),
#   ('appreci', 1),
#   ('capitol', 1),
#   ('deal', 1),
#   ('devil', 1),
#   ('disturb', 1),
#   ('munasono', 1),
#   ('protrump', 1),
#   ('raquelnphoto', 1),
#   ('read', 1),
#   ('riot', 1),
#   ('room', 1),
#   ('state', 1),
#   ('statesid', 1),
#   ('terribl', 1),
#   ('think', 1),
#   ('visual', 1)],
#  [('stopthest', 1),
#   ('biden', 1),
#   ('joebiden', 1),
#   ('like', 1),
#   ('turn', 2),
#   ('american', 1),
#   ('appar', 1),
#   ('appeas', 1),
#   ('away', 2),
#   ('captur', 1),
#   ('coat', 1),
#   ('desper', 1),
#   ('httpstcoa', 1),
#   ('kamalaharri', 1),
#   ('lot', 1),
#   ('mostlypeac', 1),
#   ('mtmext', 1),
#   ('oper', 1),
#   ('swamp', 1),
#   ('victor', 1),
#   ('walk', 1),
#   ('wheresthefir', 1)],
#  [('stopthest', 1)],
#  [('stopthest', 1), ('httpstcot', 1), ('ixpv', 1)],
#  [('hawleymo', 1), ('simonschust', 1), ('stopthest', 1)],
#  [('stopthest', 1),
#   ('peopl', 1),
#   ('trump', 1),
#   ('stand', 1),
#   ('help', 1),
#   ('absolut', 1),
#   ('come', 1),
#   ('continu', 1),
#   ('mrmichaelburk', 1),
#   ('pres', 1)],
#  [('stopthest', 1),
#   ('steal', 1),
#   ('emeraldrobinson', 1),
#   ('famili', 1),
#   ('friend', 1),
#   ('militari', 1),
#   ('rreactor', 1),
#   ('senat', 1),
#   ('world', 1)],
#  [('stopthest', 1), ('arizona', 1), ('httpstcov', 1), ('zrshudq', 1)],
#  [('stopthest', 1), ('tedcruz', 1)],
#  [('stopthest', 1),
#   ('peopl', 1),
#   ('httpstco', 1),
#   ('arrest', 1),
#   ('capitol', 1),
#   ('act', 1),
#   ('censur', 1),
#   ('downplay', 1),
#   ('drixand', 1),
#   ('enactth', 1),
#   ('expel', 1),
#   ('kijua', 1),
#   ('lawmak', 1),
#   ('lock', 1),
#   ('make', 1),
#   ('minim', 1),
#   ('mockeri', 1),
#   ('offens', 1),
#   ('paranoia', 1),
#   ('parrot', 1),
#   ('sediti', 1),
#   ('sieg', 1),
#   ('sjjphd', 1),
#   ('unfound', 1),
#   ('xdqdypolh', 1)],
#  [('stopthest', 1),
#   ('trump', 1),
#   ('capitol', 2),
#   ('arresttrump', 1),
#   ('capitolbuild', 1),
#   ('capitolhil', 1),
#   ('capitolriot', 2),
#   ('connect', 1),
#   ('dcpolic', 1),
#   ('impeachtrumpnow', 1),
#   ('proof', 1),
#   ('trumpout', 1),
#   ('washington', 1),
#   ('washingtondc', 1)],
#  [('stopthest', 1),
#   ('power', 1),
#   ('stop', 1),
#   ('america', 1),
#   ('bankrupt', 1),
#   ('boycott', 1),
#   ('bretbaier', 1),
#   ('civil', 1),
#   ('complex', 1),
#   ('confeder', 1),
#   ('democrat', 1),
#   ('entir', 1),
#   ('extrem', 1),
#   ('general', 1),
#   ('media', 3),
#   ('mediaisthevirus', 1),
#   ('partisan', 1),
#   ('protest', 1),
#   ('walkaway', 1)],
#  [('stopthest', 1), ('swamp', 1), ('nytim', 1), ('ultim', 1)],
#  [('stopthest', 1), ('maga', 2), ('ndelriego', 1), ('proud', 1)],
#  [('fraud', 1),
#   ('stopthest', 1),
#   ('stop', 1),
#   ('elect', 1),
#   ('state', 1),
#   ('brad', 1),
#   ('district', 1),
#   ('govrickett', 1),
#   ('hard', 1),
#   ('infiltr', 1),
#   ('protect', 1),
#   ('radicalright', 1),
#   ('rampant', 1),
#   ('senslama', 1),
#   ('support', 1),
#   ('want', 1),
#   ('work', 1)],
#  [('claim', 1),
#   ('fals', 1),
#   ('incit', 1),
#   ('stopthest', 1),
#   ('video', 1),
#   ('trump', 1),
#   ('today', 1),
#   ('like', 1),
#   ('continu', 1),
#   ('work', 1),
#   ('associ', 1),
#   ('ban', 1),
#   ('block', 2),
#   ('hashtag', 2),
#   ('httpstcojxcqg', 1),
#   ('stormthecapit', 1),
#   ('tiktok', 1),
#   ('twitter', 1)],
#  [('stopthest', 1), ('tedcruz', 1)],
#  [('fight', 1),
#   ('stopthest', 1),
#   ('eagleedmartin', 1),
#   ('periscop', 1),
#   ('wynk', 1),
#   ('avoid', 1),
#   ('httpstco', 1),
#   ('stand', 1),
#   ('america', 2),
#   ('blame', 1),
#   ('bless', 1),
#   ('cult', 1),
#   ('grind', 1),
#   ('hate', 1),
#   ('morn', 1),
#   ('move', 1),
#   ('penc', 1),
#   ('recap', 1),
#   ('strength', 1),
#   ('transit', 1)],
#  [('stopthest', 1),
#   ('patriot', 1),
#   ('ahead', 1),
#   ('alexjon', 1),
#   ('dcsufg', 1),
#   ('gather', 1),
#   ('gzxzjwha', 1),
#   ('httpstcodelzxla', 1),
#   ('httpstcoj', 1),
#   ('httpstcoomx', 1),
#   ('infowar', 1),
#   ('massiv', 1),
#   ('road', 1),
#   ('shut', 1)],
#  [('stopthest', 1), ('antifacapitol', 1), ('httpstcouvfi', 1), ('wfdd', 1)],
#  [('stopthest', 1),
#   ('presid', 1),
#   ('accus', 2),
#   ('attack', 1),
#   ('democraci', 1),
#   ('duli', 1),
#   ('goebbel', 1),
#   ('guilti', 1),
#   ('httpstcocw', 1),
#   ('iepanht', 1),
#   ('joseph', 1),
#   ('minist', 1),
#   ('nazi', 1),
#   ('propaganda', 1),
#   ('reelect', 1),
#   ('senschum', 1),
#   ('take', 1),
#   ('truli', 1)],
#  [('stopthest', 1),
#   ('look', 1),
#   ('bmuej', 1),
#   ('get', 1),
#   ('httpstcocpus', 1),
#   ('strang', 1)],
#  [('stopthest', 1),
#   ('trump', 1),
#   ('maga', 1),
#   ('militari', 1),
#   ('walkaway', 1),
#   ('ccot', 1),
#   ('coljoesnid', 1),
#   ('dailycal', 1),
#   ('danscavino', 1),
#   ('genz', 1),
#   ('millenni', 1),
#   ('oann', 1),
#   ('tcot', 1),
#   ('teaparti', 1)],
#  [('stopthest', 1),
#   ('trump', 1),
#   ('maga', 1),
#   ('militari', 1),
#   ('walkaway', 1),
#   ('ccot', 1),
#   ('coljoesnid', 1),
#   ('dailycal', 1),
#   ('danscavino', 1),
#   ('genz', 1),
#   ('millenni', 1),
#   ('oann', 1),
#   ('tcot', 1),
#   ('teaparti', 1)],
#  [('stopthest', 1),
#   ('maga', 1),
#   ('fightback', 1),
#   ('believ', 2),
#   ('disproven', 1),
#   ('good', 1),
#   ('idiot', 1),
#   ('rubbish', 1)],
#  [('stopthest', 1),
#   ('great', 1),
#   ('thank', 1),
#   ('truth', 1),
#   ('arimelb', 1),
#   ('choke', 1),
#   ('doublestandard', 1),
#   ('hypocrisi', 1),
#   ('racism', 1),
#   ('sincer', 1),
#   ('systemicrac', 1),
#   ('teller', 1)],
#  [('stopthest', 1),
#   ('fightfortrump', 1),
#   ('trumpsupport', 1),
#   ('support', 1),
#   ('twitter', 1),
#   ('hate', 1),
#   ('altern', 1),
#   ('bigtech', 1),
#   ('bitchut', 1),
#   ('facebook', 1),
#   ('mew', 1),
#   ('mtgreene', 1),
#   ('parlerapp', 1),
#   ('pass', 1),
#   ('plummet', 1),
#   ('pumpkin', 1),
#   ('realdonaldtrump', 1),
#   ('rumbl', 1),
#   ('stock', 1),
#   ('tech', 1),
#   ('watch', 1),
#   ('youtub', 1)],
#  [('stopthest', 1),
#   ('protest', 1),
#   ('bigger', 1),
#   ('dineshdsouza', 1),
#   ('enslav', 1),
#   ('free', 2),
#   ('patriotparti', 1),
#   ('press', 1),
#   ('problem', 1),
#   ('shall', 1),
#   ('vote', 3),
#   ('worth', 1)],
#  [('stopthest', 1),
#   ('saveamerica', 1),
#   ('stopthecoup', 1),
#   ('press', 1),
#   ('brief', 1),
#   ('hous', 1),
#   ('httpstcoy', 1),
#   ('kayleigh', 2),
#   ('mcenani', 2),
#   ('pressbrief', 1),
#   ('sqtygk', 1),
#   ('white', 1),
#   ('whitehous', 1)],
#  [('stopthest', 1), ('fake', 1), ('pictur', 1), ('use', 1)],
#  [('stopthest', 1),
#   ('love', 2),
#   ('wethepeopl', 1),
#   ('antifa', 1),
#   ('prayforamerica', 1),
#   ('patriot', 1),
#   ('traitor', 1),
#   ('pray', 1),
#   ('america', 1),
#   ('penc', 1),
#   ('ash', 1),
#   ('ashlibabbitt', 1),
#   ('babbitt', 1),
#   ('electionfraud', 1),
#   ('freedom', 1),
#   ('httpstcoxv', 1),
#   ('one', 1),
#   ('peac', 1),
#   ('ripashlibabbitt', 1),
#   ('serv', 1),
#   ('veteran', 1)],
#  [('fight', 1),
#   ('stopthest', 1),
#   ('presid', 1),
#   ('trump', 1),
#   ('countri', 1),
#   ('evid', 1),
#   ('pray', 1),
#   ('continu', 1),
#   ('america', 1),
#   ('want', 1),
#   ('choos', 1),
#   ('codemonkeyz', 1),
#   ('decis', 1),
#   ('forev', 1),
#   ('grate', 1),
#   ('incred', 1),
#   ('respect', 1),
#   ('servic', 1)],
#  [('stopthest', 1), ('italyditit', 1)],
#  [('stopthest', 1), ('walkaway', 1)],
#  [('stopthest', 1),
#   ('peopl', 1),
#   ('trump', 1),
#   ('maga', 1),
#   ('think', 1),
#   ('arizona', 1),
#   ('hypocrisi', 1),
#   ('realdonaldtrump', 1),
#   ('arent', 1),
#   ('ask', 1),
#   ('azgop', 1),
#   ('conserv', 1),
#   ('evangel', 1),
#   ('folk', 1),
#   ('golli', 1),
#   ('httpstcoyajqox', 1),
#   ('kelliwardaz', 1),
#   ('littl', 1),
#   ('looke', 1),
#   ('republican', 1),
#   ('trumptan', 1)],
#  [('fraud', 1),
#   ('stopthest', 1),
#   ('steal', 1),
#   ('elect', 1),
#   ('want', 1),
#   ('vote', 1),
#   ('burn', 1),
#   ('nation', 1),
#   ('offic', 1),
#   ('post', 1),
#   ('readi', 1),
#   ('renam', 1),
#   ('repdlesko', 1),
#   ('smdh', 1)],
#  [('stopthest', 1),
#   ('peopl', 1),
#   ('power', 1),
#   ('maga', 1),
#   ('come', 1),
#   ('attack', 1),
#   ('discuss', 1),
#   ('januari', 1),
#   ('second', 1),
#   ('wide', 1)],
#  [('court', 2),
#   ('fraud', 2),
#   ('stopthest', 1),
#   ('look', 1),
#   ('evid', 2),
#   ('like', 1),
#   ('walkaway', 1),
#   ('decid', 1),
#   ('widespread', 2)],
#  [('court', 2),
#   ('fraud', 2),
#   ('stopthest', 1),
#   ('look', 1),
#   ('evid', 2),
#   ('like', 1),
#   ('walkaway', 1),
#   ('decid', 1),
#   ('widespread', 2),
#   ('crnc', 1),
#   ('wacollegegop', 1)],
#  [('stopthest', 1),
#   ('presid', 1),
#   ('realdonaldtrump', 1),
#   ('decid', 1),
#   ('globalist', 1),
#   ('puppet', 1),
#   ('replac', 1),
#   ('reveal', 1)],
#  [('fraud', 1),
#   ('stopthest', 1),
#   ('voter', 1),
#   ('presid', 1),
#   ('trump', 1),
#   ('maga', 1),
#   ('stop', 1),
#   ('support', 1),
#   ('realdonaldtrump', 1),
#   ('agre', 1),
#   ('amacforamerica', 1),
#   ('geib', 1),
#   ('httpstcoffokd', 1),
#   ('matureamerican', 1),
#   ('petit', 1),
#   ('retweet', 1),
#   ('rudygiuliani', 1),
#   ('sign', 1)],
#  [('stopthest', 1),
#   ('steal', 1),
#   ('elect', 1),
#   ('one', 1),
#   ('excus', 1),
#   ('forget', 1),
#   ('goplead', 1),
#   ('law', 1),
#   ('refer', 1),
#   ('wewillnot', 1)],
#  [('stopthest', 1), ('begin', 1), ('catturd', 1)],
#  [('stopthest', 1),
#   ('maga', 1),
#   ('bring', 1),
#   ('capitol', 1),
#   ('riot', 1),
#   ('capit', 1),
#   ('charg', 1),
#   ('feder', 1),
#   ('follow', 1),
#   ('httpstcouxirvz', 1),
#   ('prosecutor', 1)],
#  [('stopthest', 1), ('game', 1), ('httpstconxk', 1)],
#  [('stopthest', 1), ('stopthesteai', 2), ('httpstcojt', 1), ('snnobw', 1)],
#  [('stopthest', 1),
#   ('dont', 1),
#   ('know', 1),
#   ('piss', 1),
#   ('mean', 1),
#   ('think', 1),
#   ('american', 1),
#   ('vote', 1),
#   ('catturd', 1),
#   ('jack', 1),
#   ('markdic', 1),
#   ('scar', 1)],
#  [('stopthest', 1),
#   ('peopl', 1),
#   ('stopthesteai', 1),
#   ('know', 1),
#   ('eaterchicago', 1),
#   ('httpstcoyx', 1),
#   ('vietnames', 1),
#   ('what', 1)],
#  [('stopthest', 1), ('wwga', 1)],
#  [('stopthest', 1),
#   ('video', 1),
#   ('say', 1),
#   ('like', 1),
#   ('sign', 1),
#   ('religi', 1),
#   ('saccon', 1),
#   ('senwilliamspa', 1),
#   ('sweet', 1),
#   ('terror', 1),
#   ('terrorist', 1),
#   ('trust', 1),
#   ('version', 1),
#   ('xtian', 1)],
#  [('stopthest', 1),
#   ('trump', 1),
#   ('countri', 1),
#   ('divid', 1),
#   ('million', 1),
#   ('result', 1),
#   ('richer', 1)],
#  [('stopthest', 1),
#   ('say', 1),
#   ('trump', 1),
#   ('think', 1),
#   ('believ', 1),
#   ('azgop', 1),
#   ('repdlesko', 1),
#   ('absurd', 1),
#   ('atroc', 1),
#   ('commit', 1),
#   ('croni', 1),
#   ('donald', 1),
#   ('drpaulgosar', 1),
#   ('famous', 1),
#   ('hitler', 1),
#   ('john', 1),
#   ('kelli', 1),
#   ('mussolini', 1),
#   ('philosoph', 1),
#   ('repandybiggsaz', 1),
#   ('stopthesq', 1),
#   ('ward', 1)],
#  [('stopthest', 1),
#   ('peopl', 1),
#   ('vote', 1),
#   ('address', 1),
#   ('author', 1),
#   ('deni', 1),
#   ('fail', 1),
#   ('irregular', 1),
#   ('stillgray', 1),
#   ('voic', 1)],
#  [('care', 1),
#   ('stopthest', 1),
#   ('trump', 1),
#   ('antifa', 1),
#   ('yesterday', 1),
#   ('like', 1),
#   ('protest', 1),
#   ('support', 1),
#   ('approxim', 2),
#   ('crimin', 2),
#   ('hear', 1),
#   ('liber', 1),
#   ('month', 1),
#   ('percentag', 2),
#   ('ralli', 1),
#   ('time', 1)],
#  [('stopthest', 1),
#   ('build', 1),
#   ('yesterday', 1),
#   ('leav', 1),
#   ('hear', 1),
#   ('asid', 1),
#   ('compar', 1),
#   ('generat', 1),
#   ('greatest', 1),
#   ('happen', 1),
#   ('harbor', 1),
#   ('hart', 1),
#   ('hypocrit', 1),
#   ('insult', 1),
#   ('kavanaugh', 1),
#   ('pearl', 1),
#   ('schumer', 1),
#   ('storm', 1),
#   ('summer', 1)],
#  [('stopthest', 1), ('chanc', 1), ('fixthefraud', 1), ('lose', 1)],
#  [('stopthest', 1), ('trumpwon', 1), ('outnumb', 1)],
#  [('stopthest', 1),
#   ('trump', 1),
#   ('didnt', 1),
#   ('fail', 1),
#   ('hat', 1),
#   ('loser', 1)],
#  [('claim', 1),
#   ('stopthest', 1),
#   ('away', 1),
#   ('media', 1),
#   ('blame', 1),
#   ('realdonaldtrump', 1),
#   ('vote', 1),
#   ('certifi', 1),
#   ('constitut', 1),
#   ('contest', 1),
#   ('coup', 1),
#   ('elector', 1),
#   ('godisincontrol', 1),
#   ('mikep', 1),
#   ('misinform', 1),
#   ('momentum', 1),
#   ('plan', 1),
#   ('theangiestanton', 1),
#   ('uphold', 1),
#   ('violenc', 1)],
#  [('stopthest', 1), ('trump', 2), ('httpstcoogkvyo', 1), ('voterfraud', 1)],
#  [('stopthest', 1),
#   ('presid', 1),
#   ('trump', 1),
#   ('elect', 1),
#   ('right', 1),
#   ('yesterday', 1),
#   ('media', 1),
#   ('protest', 1),
#   ('blame', 1),
#   ('democraci', 1),
#   ('realdonaldtrump', 1),
#   ('happen', 1),
#   ('constitut', 1),
#   ('essenti', 1),
#   ('rememb', 1),
#   ('rig', 1),
#   ('social', 1),
#   ('whos', 1)],
#  [('stopthest', 1),
#   ('trump', 1),
#   ('american', 1),
#   ('chao', 1),
#   ('china', 1),
#   ('italydidit', 1),
#   ('politician', 1),
#   ('real', 1),
#   ('staff', 1),
#   ('tosaveamerica', 1)],
#  [('stopthest', 1),
#   ('thank', 1),
#   ('good', 1),
#   ('terrorist', 1),
#   ('xtian', 1),
#   ('disgrac', 1),
#   ('fawk', 1),
#   ('news', 1),
#   ('quit', 1),
#   ('vincent', 1)],
#  [('stopthest', 1)],
#  [('stopthest', 1),
#   ('peopl', 1),
#   ('trump', 1),
#   ('protest', 1),
#   ('sincer', 1),
#   ('hypocrit', 1),
#   ('balot', 1),
#   ('berni', 1),
#   ('cheat', 1),
#   ('dear', 1),
#   ('debat', 1),
#   ('dick', 1),
#   ('handcuff', 1),
#   ('hell', 1),
#   ('isnt', 1),
#   ('jill', 1),
#   ('kick', 1),
#   ('primari', 1),
#   ('principl', 1),
#   ('savior', 1),
#   ('stein', 1),
#   ('yorker', 1)],
#  [('stopthest', 1), ('maga', 1), ('capit', 1)],
#  [('stopthest', 1),
#   ('maga', 2),
#   ('danscavino', 1),
#   ('realdonaldtrump', 1),
#   ('gtrainrob', 1),
#   ('readylet', 1)],
#  [('stopthest', 1),
#   ('trump', 1),
#   ('right', 1),
#   ('httpstcog', 1),
#   ('middl', 1),
#   ('speakerpelosi', 1),
#   ('wmwcgi', 1)],
#  [('stopthest', 1), ('elect', 1), ('fraudul', 1), ('theleoterrel', 1)],
#  [('stopthest', 1),
#   ('video', 1),
#   ('httpstco', 1),
#   ('capitol', 1),
#   ('electionfraud', 1),
#   ('author', 1),
#   ('barricad', 1),
#   ('htzhnmg', 1),
#   ('protestor', 1),
#   ('usher', 1)],
#  [('stopthest', 1),
#   ('word', 1),
#   ('watch', 1),
#   ('ash', 1),
#   ('babbitt', 1),
#   ('real', 1),
#   ('colour', 1),
#   ('day', 1),
#   ('presssec', 1),
#   ('true', 1)],
#  [('stopthest', 1), ('know', 1), ('exact', 1), ('deni', 1), ('azhous', 1)],
#  [('stopthest', 1),
#   ('antifa', 1),
#   ('httpstco', 1),
#   ('game', 1),
#   ('emydjim', 1)],
#  [('stopthest', 1),
#   ('maga', 1),
#   ('traitor', 1),
#   ('amen', 1),
#   ('buri', 1),
#   ('grave', 1),
#   ('unmark', 1)],
#  [('stopthest', 1),
#   ('twitter', 1),
#   ('nation', 1),
#   ('divid', 1),
#   ('heal', 1),
#   ('trend', 1)],
#  [('hawleymo', 1),
#   ('stopthest', 1),
#   ('fourmoreyear', 1),
#   ('today', 1),
#   ('away', 1),
#   ('brianstelt', 1),
#   ('close', 1),
#   ('door', 1),
#   ('fyhwasv', 1),
#   ('httpstcopq', 1),
#   ('josh', 1),
#   ('open', 1),
#   ('sentedcruz', 1),
#   ('tomorrow', 1)],
#  [('fraud', 1),
#   ('stopthest', 1),
#   ('write', 1),
#   ('httpstco', 1),
#   ('elect', 2),
#   ('draintheswamp', 1),
#   ('state', 1),
#   ('watch', 1),
#   ('canada', 1),
#   ('confess', 1),
#   ('erinotool', 1),
#   ('fordnat', 1),
#   ('hack', 1),
#   ('idea', 1),
#   ('itali', 2),
#   ('newworldord', 1),
#   ('onpoli', 1),
#   ('polit', 1),
#   ('softwar', 1),
#   ('uspoli', 1),
#   ('whistleblow', 1),
#   ('writer', 1)],
#  [('stopthest', 1),
#   ('antifaterrorist', 1),
#   ('dwwoee', 1),
#   ('fweedom', 1),
#   ('httpstcokyw', 1)],
#  [('stopthest', 1), ('love', 1)],
#  [('stopthest', 1), ('advic', 1), ('ungovern', 1)],
#  [('incit', 1),
#   ('stopthest', 1),
#   ('riot', 1),
#   ('uphold', 1),
#   ('briansimspa', 1),
#   ('dougmastriano', 1),
#   ('failur', 1),
#   ('insurrect', 1),
#   ('oath', 1),
#   ('sentimkearney', 1),
#   ('trumpral', 1),
#   ('trumptrain', 1)],
#  [('stopthest', 1),
#   ('polic', 1),
#   ('state', 1),
#   ('think', 1),
#   ('desper', 1),
#   ('want', 1),
#   ('apparatus', 1),
#   ('creat', 1),
#   ('deep', 1),
#   ('repress', 1),
#   ('zani', 1)],
#  [('fraud', 1),
#   ('statement', 1),
#   ('stopthest', 1),
#   ('say', 1),
#   ('trump', 1),
#   ('elect', 1),
#   ('justic', 1),
#   ('american', 1),
#   ('free', 1),
#   ('vote', 1),
#   ('nation', 1),
#   ('conduct', 1),
#   ('depart', 2),
#   ('describ', 1),
#   ('donaldjtrump', 1),
#   ('histori', 1),
#   ('homeland', 2),
#   ('releas', 1),
#   ('sebgorka', 1),
#   ('secur', 3),
#   ('thief', 1)],
#  [('stopthest', 1), ('maga', 1)],
#  [('stopthest', 1),
#   ('month', 1),
#   ('allow', 1),
#   ('group', 1),
#   ('markruffalo', 1),
#   ('organ', 1),
#   ('platform', 1),
#   ('report', 1),
#   ('respons', 1),
#   ('zuck', 1)],
#  [('fraud', 1),
#   ('statement', 1),
#   ('stopthest', 1),
#   ('say', 1),
#   ('trump', 1),
#   ('elect', 1),
#   ('justic', 1),
#   ('american', 1),
#   ('free', 1),
#   ('vote', 1),
#   ('nation', 1),
#   ('conduct', 1),
#   ('depart', 2),
#   ('describ', 1),
#   ('donaldjtrump', 1),
#   ('histori', 1),
#   ('homeland', 2),
#   ('releas', 1),
#   ('secur', 3),
#   ('thief', 1),
#   ('kyliejanekrem', 1)],
#  [('fraud', 1),
#   ('statement', 1),
#   ('stopthest', 1),
#   ('say', 1),
#   ('trump', 1),
#   ('elect', 1),
#   ('justic', 1),
#   ('american', 1),
#   ('free', 1),
#   ('vote', 1),
#   ('nation', 1),
#   ('conduct', 1),
#   ('depart', 2),
#   ('describ', 1),
#   ('donaldjtrump', 1),
#   ('histori', 1),
#   ('homeland', 2),
#   ('releas', 1),
#   ('secur', 3),
#   ('thief', 1),
#   ('markfinchem', 1)],
#  [('stopthest', 1), ('malcolmkenyatta', 1), ('wrong', 1)],
#  [('stopthest', 1),
#   ('peopl', 1),
#   ('traitor', 1),
#   ('right', 1),
#   ('arrest', 1),
#   ('deal', 1),
#   ('schumer', 1),
#   ('mikep', 1),
#   ('insurrect', 1),
#   ('group', 1),
#   ('father', 1),
#   ('found', 1),
#   ('includ', 1),
#   ('iran', 1),
#   ('iraq', 1),
#   ('pelosi', 1),
#   ('savetherepubl', 1),
#   ('sedit', 1),
#   ('treason', 1)],
#  [('stopthest', 1),
#   ('militari', 1),
#   ('coup', 1),
#   ('httpstcoc', 1),
#   ('inaugur', 1),
#   ('sunday', 1),
#   ('till', 2)],
#  [('fraud', 1),
#   ('statement', 1),
#   ('stopthest', 1),
#   ('say', 1),
#   ('trump', 1),
#   ('elect', 1),
#   ('justic', 1),
#   ('american', 1),
#   ('free', 1),
#   ('vote', 1),
#   ('nation', 1),
#   ('conduct', 1),
#   ('depart', 2),
#   ('describ', 1),
#   ('donaldjtrump', 1),
#   ('histori', 1),
#   ('homeland', 2),
#   ('releas', 1),
#   ('secur', 3),
#   ('thief', 1)],
#  [('stopthest', 1),
#   ('republican', 1),
#   ('constitut', 1),
#   ('complet', 2),
#   ('control', 1),
#   ('dem', 1),
#   ('fair', 1),
#   ('georgia', 1),
#   ('governor', 1),
#   ('hamburglarh', 1),
#   ('illeg', 1),
#   ('inform', 1),
#   ('newsmax', 1),
#   ('rockdog', 1),
#   ('spineless', 1)],
#  [('stopthest', 1),
#   ('love', 1),
#   ('peopl', 1),
#   ('right', 1),
#   ('leav', 1),
#   ('come', 1),
#   ('realdonaldtrump', 1),
#   ('puppet', 1),
#   ('corrupt', 1),
#   ('discard', 1),
#   ('fuckhead', 1),
#   ('govern', 1),
#   ('master', 1),
#   ('overthrow', 1),
#   ('usefulidiot', 1)],
#  [('stopthest', 1),
#   ('peopl', 1),
#   ('say', 1),
#   ('know', 1),
#   ('trumpwon', 1),
#   ('truth', 2),
#   ('today', 1),
#   ('want', 1),
#   ('million', 1),
#   ('greg', 1),
#   ('gutfeld', 1),
#   ('jess', 1),
#   ('watter', 1)],
#  [('stopthest', 1)],
#  [('stopthest', 1),
#   ('antifaterrorist', 1),
#   ('fweedom', 1),
#   ('httpstcolzwee', 1)],
#  [('stopthest', 1),
#   ('say', 1),
#   ('feder', 1),
#   ('follow', 1),
#   ('john', 1),
#   ('constitut', 3),
#   ('elector', 1),
#   ('accord', 1),
#   ('dubious', 1),
#   ('eastman', 1),
#   ('highest', 1),
#   ('land', 1),
#   ('lawyer', 1),
#   ('randpaul', 1),
#   ('republ', 1),
#   ('ruleoflaw', 1)],
#  [('stopthest', 1)],
#  [('stopthest', 1), ('mew', 1), ('pass', 1), ('retweet', 1), ('compromis', 1)],
#  [('stopthest', 1),
#   ('capitolriot', 1),
#   ('forget', 1),
#   ('httpstcop', 1),
#   ('newsday', 1),
#   ('rowley', 2),
#   ('tobago', 1),
#   ('trinidad', 1),
#   ('updat', 1),
#   ('usriot', 1)],
#  [('stopthest', 1),
#   ('trumpwon', 1),
#   ('antifaterrorist', 1),
#   ('bidench', 1),
#   ('freespeecham', 1)],
#  [('stopthest', 1),
#   ('great', 1),
#   ('post', 1),
#   ('realcandaceo', 1),
#   ('redpillblack', 1),
#   ('rofl', 1)],
#  [('stopthest', 1),
#   ('presid', 1),
#   ('biden', 1),
#   ('patriot', 1),
#   ('holdthelin', 1),
#   ('think', 3),
#   ('militari', 2),
#   ('happen', 1),
#   ('elimin', 1),
#   ('emot', 1),
#   ('logic', 1),
#   ('nonsens', 1),
#   ('takeov', 1),
#   ('tell', 1)],
#  [('stopthest', 1),
#   ('presid', 1),
#   ('wethepeopl', 1),
#   ('come', 2),
#   ('world', 1),
#   ('free', 1),
#   ('ksorb', 1)],
#  [('fals', 1),
#   ('fraud', 1),
#   ('stopthest', 1),
#   ('trump', 1),
#   ('elect', 1),
#   ('yesterday', 1),
#   ('support', 2),
#   ('democraci', 1),
#   ('follow', 1),
#   ('real', 1),
#   ('insurrect', 1),
#   ('apologist', 1),
#   ('ingrahamangl', 2),
#   ('narrat', 1),
#   ('see', 1),
#   ('tyranni', 1),
#   ('whove', 1)],
#  [('stopthest', 1),
#   ('senat', 1),
#   ('accomplish', 1),
#   ('children', 1),
#   ('filthi', 1),
#   ('guess', 1),
#   ('leverag', 1),
#   ('money', 1),
#   ('nice', 1),
#   ('rich', 1),
#   ('yaay', 1),
#   ('year', 1)],
#  [('stopthest', 1),
#   ('trump', 1),
#   ('httpstco', 1),
#   ('washington', 1),
#   ('mpknv', 1),
#   ('qanon', 1)],
#  [('stopthest', 1),
#   ('trump', 1),
#   ('maga', 1),
#   ('leav', 1),
#   ('come', 1),
#   ('support', 1),
#   ('dcralli', 1),
#   ('fool', 1),
#   ('forc', 1),
#   ('fulli', 1),
#   ('hmmmm', 1)],
#  [('stopthest', 1),
#   ('trump', 1),
#   ('support', 1),
#   ('attent', 1),
#   ('demon', 1),
#   ('everyon', 1),
#   ('sirhottest', 1),
#   ('structur', 1),
#   ('thing', 1)],
#  [('stopthest', 1), ('trumpwon', 1), ('censorship', 1), ('farcebook', 1)],
#  [('stopthest', 1),
#   ('word', 1),
#   ('today', 1),
#   ('take', 1),
#   ('offic', 1),
#   ('constitut', 1),
#   ('agenda', 1),
#   ('agendasam', 1),
#   ('bibl', 1),
#   ('byrd', 1),
#   ('dark', 1),
#   ('impos', 1),
#   ('intend', 1),
#   ('live', 1),
#   ('quot', 2),
#   ('redefin', 1),
#   ('sacr', 1),
#   ('satanist', 1),
#   ('thought', 1),
#   ('twist', 1)],
#  [('fight', 1), ('hawleymo', 1), ('stopthest', 1), ('missouristrong', 1)],
#  [('stopthest', 1),
#   ('prayforamerica', 1),
#   ('patriot', 1),
#   ('holdthelin', 1),
#   ('httpstco', 1),
#   ('clapper', 1),
#   ('fjqh', 1),
#   ('godblessamerica', 1),
#   ('thestorm', 1)],
#  [('stopthest', 1),
#   ('peopl', 1),
#   ('httpstco', 1),
#   ('yesterday', 1),
#   ('american', 1),
#   ('complet', 1),
#   ('corruptgop', 1),
#   ('demsli', 1),
#   ('final', 1),
#   ('rundown', 1),
#   ('standfirm', 1),
#   ('tupbj', 1)],
#  [('fraud', 1),
#   ('stopthest', 1),
#   ('trump', 1),
#   ('friend', 1),
#   ('take', 2),
#   ('charg', 1),
#   ('million', 1),
#   ('chao', 1),
#   ('ahvq', 1),
#   ('donaldtrumpjr', 1),
#   ('fundrais', 1),
#   ('girlfriend', 1),
#   ('gofraudm', 1),
#   ('httpstcowov', 1),
#   ('indict', 1),
#   ('lie', 1),
#   ('stevebannon', 1),
#   ('trumptaxreturn', 1),
#   ('veger', 1)],
#  [('stopthest', 1),
#   ('presid', 1),
#   ('peopl', 1),
#   ('trump', 1),
#   ('maga', 1),
#   ('steal', 1),
#   ('elect', 1),
#   ('realdonaldtrump', 1),
#   ('vote', 1),
#   ('charg', 1),
#   ('happen', 1),
#   ('fraudul', 1),
#   ('allow', 1),
#   ('confisc', 1),
#   ('domain', 1),
#   ('expos', 1),
#   ('machin', 1),
#   ('need', 1),
#   ('neveragain', 1),
#   ('seiz', 1)],
#  [('stopthest', 1),
#   ('fightforamerica', 1),
#   ('fightfortrump', 1),
#   ('bgonthescen', 1)],
#  [('stopthest', 1),
#   ('joebiden', 1),
#   ('wethepeopl', 1),
#   ('antifa', 1),
#   ('traitor', 1),
#   ('fightforamerica', 1),
#   ('fightforfreedom', 1),
#   ('fightfortrump', 1),
#   ('pray', 1),
#   ('america', 1),
#   ('democrat', 1),
#   ('penc', 1),
#   ('bigtech', 1),
#   ('ashlibabbitt', 1),
#   ('electionfraud', 1),
#   ('republ', 1),
#   ('danbongino', 1),
#   ('httpstcoigqzk', 1),
#   ('laxj', 1),
#   ('seanhann', 1)],
#  [('stopthest', 1),
#   ('antifaterrorist', 1),
#   ('fweedom', 1),
#   ('httpstcoydo', 1)],
#  [('fals', 1),
#   ('fraud', 1),
#   ('stopthest', 1),
#   ('trump', 1),
#   ('elect', 1),
#   ('build', 2),
#   ('yesterday', 1),
#   ('work', 1),
#   ('democraci', 1),
#   ('presssec', 1),
#   ('insurrect', 1),
#   ('respons', 1),
#   ('narrat', 1),
#   ('attempt', 1),
#   ('birther', 1),
#   ('chiefli', 1),
#   ('clear', 1),
#   ('divis', 1),
#   ('elistokol', 1),
#   ('gtconway', 1),
#   ('june', 1),
#   ('violent', 1)],
#  [('stopthest', 1),
#   ('power', 2),
#   ('countri', 1),
#   ('washington', 1),
#   ('democrat', 1),
#   ('nazi', 1),
#   ('hitler', 1),
#   ('happen', 2),
#   ('illeg', 1),
#   ('seiz', 1),
#   ('fascist', 1),
#   ('germani', 1),
#   ('prior', 1),
#   ('recent', 1),
#   ('rise', 1),
#   ('scari', 1),
#   ('similar', 1)],
#  [('stopthest', 1),
#   ('unit', 1),
#   ('maga', 1),
#   ('httpstco', 1),
#   ('build', 1),
#   ('shoot', 1),
#   ('capitol', 1),
#   ('state', 1),
#   ('ash', 1),
#   ('ashlibabbitt', 1),
#   ('babbitt', 1),
#   ('stillgray', 1),
#   ('insurrect', 1),
#   ('assault', 1),
#   ('brettwca', 1),
#   ('extremist', 1),
#   ('farright', 1),
#   ('fix', 1),
#   ('kill', 1),
#   ('nyzyirqqz', 1),
#   ('particip', 1),
#   ('summersun', 1)],
#  [('stopthest', 1),
#   ('trump', 1),
#   ('amend', 1),
#   ('save', 1),
#   ('realdonaldtrump', 1),
#   ('freedom', 1),
#   ('chanc', 1),
#   ('contest', 1),
#   ('isnt', 1),
#   ('kick', 1),
#   ('bigbob', 1),
#   ('catch', 1),
#   ('cockmeat', 1),
#   ('freespeech', 1),
#   ('gitmo', 1),
#   ('httpstconofz', 1),
#   ('invok', 1),
#   ('leg', 1),
#   ('theyll', 1),
#   ('wonder', 1)],
#  [('stopthest', 1),
#   ('presid', 1),
#   ('apolog', 1),
#   ('biden', 1),
#   ('eagleedmartin', 1),
#   ('gfzt', 1),
#   ('httpstcoobiy', 1),
#   ('joebiden', 1),
#   ('peopl', 1),
#   ('periscop', 1),
#   ('pledg', 1),
#   ('plus', 1),
#   ('power', 1),
#   ('say', 1),
#   ('wynk', 1),
#   ('oppos', 1)],
#  [('stopthest', 1),
#   ('peopl', 2),
#   ('look', 1),
#   ('dont', 1),
#   ('elect', 1),
#   ('understand', 1),
#   ('think', 1),
#   ('believ', 1),
#   ('watch', 1),
#   ('forget', 1),
#   ('result', 1),
#   ('berni', 1),
#   ('dem', 1),
#   ('audi', 1),
#   ('foeva', 1),
#   ('fuckeri', 1),
#   ('mtracey', 1),
#   ('notic', 1),
#   ('oliviaask', 1),
#   ('screw', 1),
#   ('shit', 1)],
#  [('stopthest', 1), ('gthtwitter', 1), ('httpstcoyj', 1), ('qjfsvl', 1)],
#  [('stopthest', 1),
#   ('patriot', 1),
#   ('riot', 1),
#   ('protest', 1),
#   ('ralli', 1),
#   ('compar', 2),
#   ('china', 1),
#   ('breitbartnew', 1),
#   ('chines', 1),
#   ('foreign', 1),
#   ('freedomlov', 1),
#   ('hong', 2),
#   ('honor', 1),
#   ('kong', 2),
#   ('ministri', 1)],
#  [('stopthest', 1),
#   ('patriot', 2),
#   ('traitor', 1),
#   ('httpstco', 1),
#   ('twitter', 1),
#   ('qanon', 1),
#   ('linwood', 1),
#   ('parler', 1),
#   ('prosecut', 1),
#   ('seditionist', 1)],
#  [('stopthest', 1),
#   ('peopl', 1),
#   ('maga', 1),
#   ('offic', 1),
#   ('januari', 1),
#   ('wave', 1)],
#  [('stopthest', 1),
#   ('stopthecoup', 1),
#   ('trumpwon', 1),
#   ('doubt', 1),
#   ('primaryrino', 1)],
#  [('fraud', 1),
#   ('stopthest', 1),
#   ('presid', 1),
#   ('elect', 1),
#   ('know', 1),
#   ('yesterday', 1),
#   ('take', 1),
#   ('problem', 1),
#   ('commit', 1),
#   ('liber', 1),
#   ('insurrect', 1),
#   ('newsmax', 1),
#   ('extremist', 1),
#   ('chris', 1),
#   ('invit', 1),
#   ('retrumplican', 1),
#   ('salcedo', 1),
#   ('socialist', 1),
#   ('talk', 1),
#   ('wanna', 1)],
#  [('stopthest', 1),
#   ('antifa', 2),
#   ('capitol', 1),
#   ('admit', 3),
#   ('articl', 1),
#   ('break', 1),
#   ('httpstcoihtpyz', 1),
#   ('imag', 1),
#   ('pay', 3)],
#  [('stopthest', 1),
#   ('look', 1),
#   ('steal', 1),
#   ('stopthecoup', 1),
#   ('elect', 1),
#   ('trumpwon', 1),
#   ('think', 1),
#   ('fraudul', 1),
#   ('primaryrino', 1),
#   ('grossli', 1),
#   ('lesson', 1)],
#  [('stopthest', 1), ('elect', 1), ('isnt', 1), ('hillari', 1)],
#  [('stopthest', 1),
#   ('fightback', 1),
#   ('elect', 2),
#   ('vote', 1),
#   ('georgiarunoff', 1),
#   ('httpstcoztgj', 1),
#   ('koyn', 1),
#   ('overturn', 1),
#   ('stormthecapitol', 1),
#   ('westvirginia', 1)],
#  [('stopthest', 1), ('stopthesteai', 1), ('antifa', 1), ('httpstcoihtpyz', 1)],
#  [('fraud', 1), ('stopthest', 1)],
#  [('stopthest', 1), ('stopthesteai', 1), ('httpstco', 1), ('fvohw', 1)],
#  [('go', 1),
#   ('stopthest', 1),
#   ('look', 1),
#   ('think', 1),
#   ('american', 1),
#   ('senat', 1),
#   ('lock', 1),
#   ('protect', 1),
#   ('get', 1),
#   ('freedom', 1),
#   ('essenti', 1),
#   ('idiotpoop', 1),
#   ('institut', 1),
#   ('prize', 1),
#   ('sovereign', 1)],
#  [('stopthest', 1),
#   ('joebiden', 1),
#   ('steal', 1),
#   ('antifa', 2),
#   ('patriot', 1),
#   ('protest', 1),
#   ('blame', 1),
#   ('peac', 1),
#   ('plan', 1),
#   ('violenc', 1),
#   ('respons', 1),
#   ('corrupt', 1),
#   ('violent', 1),
#   ('easi', 1),
#   ('obvious', 1),
#   ('punt', 1),
#   ('riggedelect', 1),
#   ('scotus', 1),
#   ('solv', 1),
#   ('stag', 1),
#   ('stagedplan', 1),
#   ('thug', 1)],
#  [('fraud', 1),
#   ('stopthest', 1),
#   ('voter', 1),
#   ('look', 1),
#   ('maga', 1),
#   ('patriot', 1),
#   ('stand', 1),
#   ('thank', 1),
#   ('yesterday', 1),
#   ('sediti', 1),
#   ('realdonaldtrump', 1),
#   ('goplead', 1),
#   ('bastard', 1),
#   ('censor', 1),
#   ('head', 1),
#   ('join', 1),
#   ('kajo', 1),
#   ('line', 1),
#   ('patriotsunit', 1),
#   ('tri', 1),
#   ('tweet', 1)],
#  [('stopthest', 1),
#   ('peopl', 1),
#   ('trump', 1),
#   ('truth', 1),
#   ('show', 1),
#   ('support', 1),
#   ('realdonaldtrump', 1),
#   ('donald', 1),
#   ('erictrump', 1),
#   ('ivankatrump', 1),
#   ('laraleatrump', 1)],
#  [('stopthest', 1),
#   ('peopl', 1),
#   ('dont', 1),
#   ('truth', 1),
#   ('like', 1),
#   ('american', 1),
#   ('democraci', 1),
#   ('follow', 1),
#   ('twist', 1),
#   ('lie', 1),
#   ('aim', 1),
#   ('blind', 1),
#   ('cloth', 1),
#   ('donaldtrump', 1),
#   ('emperor', 1),
#   ('endless', 1),
#   ('fall', 1),
#   ('stupid', 1),
#   ('suit', 1),
#   ('threaten', 1),
#   ('trick', 1),
#   ('youv', 2)],
#  [('stopthest', 2),
#   ('saveamerica', 1),
#   ('fightfortrump', 2),
#   ('stopthecoup', 2),
#   ('aveamerica', 1),
#   ('httpstcod', 1),
#   ('httpstcol', 1),
#   ('ylwiw', 1)],
#  [('stopthest', 1),
#   ('lose', 1),
#   ('money', 1),
#   ('bet', 1),
#   ('kloeffler', 1),
#   ('scam', 1)],
#  [('stopthest', 1),
#   ('say', 1),
#   ('camp', 1),
#   ('ignor', 1),
#   ('american', 1),
#   ('democraci', 1),
#   ('hell', 1),
#   ('arrog', 1),
#   ('auschwitz', 1),
#   ('clifton', 1),
#   ('combin', 1),
#   ('prison', 1),
#   ('resist', 1),
#   ('trumpvirus', 1),
#   ('tshirt', 1)],
#  [('stopthest', 1), ('dbongino', 1), ('facebook', 1), ('chickapea', 1)],
#  [('stopthest', 1),
#   ('biden', 1),
#   ('bretbaier', 1),
#   ('littl', 1),
#   ('basement', 1),
#   ('benstraci', 1),
#   ('cbsnew', 1),
#   ('girlspedo', 1),
#   ('hide', 1),
#   ('pphilli', 1),
#   ('probabl', 1),
#   ('saraecook', 1),
#   ('sicko', 1),
#   ('sniff', 1)],
#  [('stopthest', 1), ('incred', 1), ('lie', 1), ('mind', 1), ('prey', 1)],
#  [('stopthest', 1),
#   ('stopthecoup', 1),
#   ('trumpwon', 1),
#   ('state', 1),
#   ('deep', 1),
#   ('primaryrino', 1),
#   ('color', 1),
#   ('execut', 1),
#   ('gatewaypundit', 1),
#   ('meat', 1),
#   ('perfect', 1),
#   ('revolut', 1),
#   ('theyr', 1)],
#  [('stopthest', 1),
#   ('peopl', 1),
#   ('trump', 1),
#   ('stand', 1),
#   ('realdonaldtrump', 1),
#   ('republican', 1),
#   ('exposetruth', 1),
#   ('finish', 1),
#   ('lead', 1),
#   ('parti', 1)],
#  [('stopthest', 1), ('httpstcobjleyhj', 1)],
#  [('stopthest', 1), ('maga', 1), ('come', 1), ('penc', 2), ('page', 1)],
#  [('stopthest', 1),
#   ('scar', 1),
#   ('davidcicillin', 1),
#   ('repraskin', 1),
#   ('reptedlieu', 1)],
#  [('scar', 1), ('davidcicillin', 1), ('reptedlieu', 1), ('ofstopthest', 1)],
#  [('stopthest', 1),
#   ('stopthesteai', 1),
#   ('understand', 1),
#   ('absolut', 1),
#   ('idiot', 1),
#   ('fail', 1),
#   ('constitut', 1),
#   ('base', 1),
#   ('failingnyt', 1),
#   ('fakenew', 1),
#   ('newspap', 1),
#   ('tomfriedman', 1)],
#  [('stopthest', 1),
#   ('presid', 1),
#   ('peopl', 1),
#   ('look', 1),
#   ('countri', 1),
#   ('like', 1),
#   ('real', 1),
#   ('allow', 1),
#   ('respons', 1),
#   ('blood', 1),
#   ('bomb', 1),
#   ('cash', 1),
#   ('danger', 1),
#   ('death', 1),
#   ('drop', 1),
#   ('hand', 1),
#   ('handout', 1),
#   ('httpstcotloj', 1),
#   ('hundr', 1),
#   ('illustr', 1),
#   ('maziehirono', 1),
#   ('thousand', 1),
#   ('wrbuj', 1)],
#  [('stopthest', 1),
#   ('think', 1),
#   ('sedit', 1),
#   ('treason', 1),
#   ('exposefraud', 1),
#   ('honest', 1),
#   ('surpris', 1)],
#  [('stopthest', 1)],
#  [('fight', 1),
#   ('stopthest', 1),
#   ('eagleedmartin', 1),
#   ('periscop', 1),
#   ('wynk', 1),
#   ('maga', 1),
#   ('httpstco', 1),
#   ('dont', 1),
#   ('stand', 1),
#   ('america', 2),
#   ('blame', 1),
#   ('bless', 1),
#   ('cult', 1),
#   ('grind', 1),
#   ('hate', 1),
#   ('morn', 1),
#   ('penc', 1),
#   ('recap', 1),
#   ('strength', 1),
#   ('transit', 1),
#   ('georgia', 1),
#   ('join', 1)],
#  [('stopthest', 1), ('stopthecoup', 1), ('trumpwon', 1), ('primaryrino', 1)],
#  [('stopthest', 1),
#   ('trump', 1),
#   ('conserv', 1),
#   ('sedit', 1),
#   ('treason', 1),
#   ('death', 1),
#   ('forerunn', 1),
#   ('httpstcoofltx', 1),
#   ('jefferson', 1),
#   ('lethargi', 1),
#   ('liberti', 1),
#   ('misconcept', 1),
#   ('public', 1),
#   ('quiet', 1),
#   ('rebel', 1),
#   ('remain', 1),
#   ('sgqi', 1),
#   ('sonsofliberti', 1),
#   ('thoma', 1)],
#  [('fight', 1),
#   ('stopthest', 1),
#   ('post', 1),
#   ('januari', 1),
#   ('insurrect', 1),
#   ('qanon', 1),
#   ('cpcbestlin', 1),
#   ('dontrumpjr', 1),
#   ('dontrumpsr', 1),
#   ('fairground', 1),
#   ('funrrc', 1),
#   ('gloria', 1),
#   ('handicap', 1),
#   ('hors', 1),
#   ('horserac', 1),
#   ('httpstcorlc', 1),
#   ('longshot', 1),
#   ('markmeadow', 1),
#   ('thursday', 1),
#   ('uscapitol', 1)],
#  [('stopthest', 1), ('stopthecoup', 1), ('trumpwon', 1), ('primaryrino', 1)],
#  [('stopthest', 1),
#   ('holdthelin', 1),
#   ('youtub', 1),
#   ('ward', 1),
#   ('see', 1),
#   ('charli', 1),
#   ('david', 1),
#   ('httpstcovx', 1),
#   ('hvccbr', 1),
#   ('park', 1),
#   ('robert', 1),
#   ('simon', 1),
#   ('steel', 1),
#   ('yall', 1)],
#  [('go', 1),
#   ('stopthest', 1),
#   ('stop', 1),
#   ('prevent', 1),
#   ('stopthecoup', 1),
#   ('trumpwon', 1),
#   ('exact', 1),
#   ('primaryrino', 1),
#   ('gatewaypundit', 1),
#   ('access', 1),
#   ('activ', 1),
#   ('atlanta', 1),
#   ('httpstcojbpxn', 1),
#   ('identifi', 1),
#   ('jone', 1),
#   ('judg', 1),
#   ('moment', 1),
#   ('order', 1),
#   ('poll', 1),
#   ('project', 1),
#   ('ralph', 1),
#   ('verita', 1),
#   ('watcher', 1)],
#  [('stopthest', 1),
#   ('evid', 1),
#   ('appar', 1),
#   ('coup', 1),
#   ('italydidit', 1),
#   ('congress', 1),
#   ('coveredup', 1),
#   ('deliv', 1),
#   ('httpstcosm', 1),
#   ('mimiflorida', 1),
#   ('paulsperri', 1)],
#  [('stopthest', 1),
#   ('trump', 1),
#   ('movement', 1),
#   ('stop', 1),
#   ('elect', 2),
#   ('know', 1),
#   ('advoc', 1),
#   ('truth', 1),
#   ('capitol', 1),
#   ('media', 1),
#   ('crimin', 1),
#   ('violenc', 1),
#   ('secur', 1),
#   ('break', 1),
#   ('brain', 1),
#   ('demand', 1),
#   ('hysteria', 1),
#   ('plain', 1),
#   ('rioter', 1),
#   ('simpl', 1),
#   ('wont', 1)],
#  [('stopthest', 1),
#   ('love', 1),
#   ('yall', 2),
#   ('outnumberedfnc', 1),
#   ('start', 1),
#   ('tomilahren', 1)],
#  [('go', 1),
#   ('claim', 1),
#   ('fals', 1),
#   ('stopthest', 1),
#   ('peopl', 1),
#   ('maga', 1),
#   ('event', 1),
#   ('believ', 1),
#   ('ralli', 1),
#   ('group', 1),
#   ('respons', 1),
#   ('qanon', 1),
#   ('live', 1),
#   ('cbsnew', 1),
#   ('revolut', 1),
#   ('attend', 1),
#   ('bobdiehl', 1),
#   ('cloudsbigsword', 1),
#   ('cost', 1),
#   ('hold', 1),
#   ('individu', 1),
#   ('longcooolwoman', 1),
#   ('shame', 1),
#   ('thecapit', 1),
#   ('unknown', 1)],
#  [('go', 1),
#   ('incit', 1),
#   ('stopthest', 1),
#   ('say', 1),
#   ('nickadamsinusa', 1),
#   ('steal', 1),
#   ('capitol', 1),
#   ('watch', 1),
#   ('capit', 1),
#   ('million', 1),
#   ('hear', 1),
#   ('parti', 1),
#   ('bank', 1),
#   ('bunker', 1),
#   ('desert', 1),
#   ('laugh', 1),
#   ('rais', 1),
#   ('rampag', 1),
#   ('sheep', 1)],
#  [('stopthest', 1)],
#  [('stopthest', 1),
#   ('patriot', 1),
#   ('januari', 1),
#   ('commit', 1),
#   ('fulli', 1),
#   ('ashlibabbit', 1),
#   ('marchfortrump', 1)],
#  [('stopthest', 1),
#   ('fightback', 1),
#   ('penc', 1),
#   ('mjahanna', 1),
#   ('tomdelong', 1),
#   ('treasonist', 1)],
#  [('go', 1),
#   ('stopthest', 1),
#   ('trump', 1),
#   ('steal', 1),
#   ('httpstco', 1),
#   ('artist', 1),
#   ('btrfcd', 1),
#   ('direct', 1),
#   ('financi', 1),
#   ('heart', 1),
#   ('song', 1),
#   ('stkiersten', 1)],
#  [('rhetor', 1),
#   ('stopthest', 1),
#   ('trump', 1),
#   ('build', 1),
#   ('shoot', 1),
#   ('capitol', 1),
#   ('capitolriot', 1),
#   ('get', 1),
#   ('ash', 1),
#   ('babbitt', 1),
#   ('ralli', 1),
#   ('attend', 1),
#   ('dead', 1),
#   ('pump', 1)],
#  [('stopthest', 1),
#   ('youtub', 1),
#   ('httpstcownb', 1),
#   ('ugflgi', 1),
#   ('warroompandem', 1)],
#  [('go', 1),
#   ('claim', 1),
#   ('fals', 1),
#   ('stopthest', 1),
#   ('peopl', 1),
#   ('maga', 1),
#   ('event', 1),
#   ('believ', 1),
#   ('ralli', 1),
#   ('group', 1),
#   ('respons', 1),
#   ('qanon', 1),
#   ('live', 1),
#   ('cbsnew', 1),
#   ('revolut', 1),
#   ('attend', 1),
#   ('cost', 1),
#   ('hold', 1),
#   ('individu', 1),
#   ('shame', 1),
#   ('thecapit', 1),
#   ('unknown', 1)],
#  [('stopthest', 1), ('maga', 1), ('caus', 1), ('prepar', 1)],
#  [('stopthest', 1),
#   ('peopl', 1),
#   ('piss', 1),
#   ('real', 1),
#   ('followgoosehead', 1),
#   ('sollenbergerrc', 1)],
#  [('go', 1),
#   ('claim', 1),
#   ('fals', 1),
#   ('stopthest', 1),
#   ('maga', 1),
#   ('event', 1),
#   ('believ', 1),
#   ('ralli', 1),
#   ('group', 1),
#   ('respons', 1),
#   ('qanon', 1),
#   ('live', 1),
#   ('revolut', 1),
#   ('attend', 1),
#   ('cost', 1),
#   ('hold', 1),
#   ('individu', 1),
#   ('shame', 1),
#   ('thecapit', 1),
#   ('unknown', 1),
#   ('buddydoyleh', 1),
#   ('jpompl', 1),
#   ('nprpolit', 1)],
#  [('incit', 1),
#   ('stopthest', 1),
#   ('video', 1),
#   ('trump', 1),
#   ('fightback', 1),
#   ('elect', 2),
#   ('peac', 1),
#   ('violenc', 1),
#   ('georgiarunoff', 1),
#   ('overturn', 1),
#   ('stormthecapitol', 1),
#   ('call', 1),
#   ('okay', 1),
#   ('sureeee', 1)],
#  [('stopthest', 1),
#   ('mean', 1),
#   ('like', 1),
#   ('crimin', 1),
#   ('blood', 1),
#   ('hand', 1),
#   ('countless', 1),
#   ('markwarn', 1)],
#  [('stopthest', 1),
#   ('trumpwon', 1),
#   ('mew', 2),
#   ('rumbl', 1),
#   ('farcebook', 1),
#   ('parler', 1),
#   ('start', 1),
#   ('copi', 1),
#   ('ditch', 1),
#   ('file', 1)],
#  [('stopthest', 1),
#   ('trump', 1),
#   ('maga', 1),
#   ('patriot', 1),
#   ('fourmoreyear', 1),
#   ('draintheswamp', 1),
#   ('insurrect', 1),
#   ('control', 1),
#   ('elvxo', 1),
#   ('httpstcoza', 1)],
#  [('stopthest', 1),
#   ('hashtag', 1),
#   ('anneman', 1),
#   ('blijft', 1),
#   ('deafspraak', 1),
#   ('gerolf', 1),
#   ('goeik', 1),
#   ('informeren', 1),
#   ('louter', 1),
#   ('mensen', 1),
#   ('toch', 1),
#   ('tweett', 1)],
#  [('go', 1),
#   ('claim', 1),
#   ('fals', 1),
#   ('stopthest', 1),
#   ('maga', 1),
#   ('event', 1),
#   ('believ', 1),
#   ('ralli', 1),
#   ('group', 1),
#   ('respons', 1),
#   ('qanon', 1),
#   ('live', 1),
#   ('revolut', 1),
#   ('attend', 1),
#   ('cost', 1),
#   ('hold', 1),
#   ('individu', 1),
#   ('shame', 1),
#   ('thecapit', 1),
#   ('unknown', 1),
#   ('jennfranconew', 1)],
#  [('stopthest', 2),
#   ('trump', 1),
#   ('maga', 1),
#   ('kraken', 1),
#   ('patriotparti', 1)],
#  [('stopthest', 1),
#   ('thank', 1),
#   ('agre', 1),
#   ('neversurrend', 1),
#   ('owen', 1),
#   ('teamtrump', 1)],
#  [('stopthest', 1),
#   ('presid', 1),
#   ('biden', 2),
#   ('america', 1),
#   ('fake', 1),
#   ('newsmax', 1),
#   ('need', 1),
#   ('divis', 1),
#   ('institut', 1),
#   ('resist', 1),
#   ('call', 1),
#   ('ahnun', 1),
#   ('doubl', 1),
#   ('half', 1),
#   ('httpstcofiyf', 1),
#   ('manhattan', 1),
#   ('racist', 1),
#   ('speech', 1),
#   ('standard', 1),
#   ('uniti', 1)],
#  [('stopthest', 1),
#   ('maga', 1),
#   ('patriot', 1),
#   ('realdonaldtrump', 1),
#   ('true', 1)],
#  [('stopthest', 1), ('tyranni', 1), ('censhorship', 1)],
#  [('stopthest', 1), ('httpstcoswrefu', 1)],
#  [('stopthest', 1),
#   ('maga', 1),
#   ('support', 1),
#   ('lose', 1),
#   ('hell', 2),
#   ('spineless', 1),
#   ('fill', 1),
#   ('rino', 2)],
#  [('stopthest', 1),
#   ('trump', 1),
#   ('maga', 1),
#   ('elect', 2),
#   ('right', 1),
#   ('realdonaldtrump', 1),
#   ('free', 1),
#   ('quot', 1),
#   ('speech', 1),
#   ('comedian', 1),
#   ('everybodi', 1),
#   ('guyatt', 1),
#   ('stopthefraud', 1)],
#  [('stopthest', 1),
#   ('httpstco', 1),
#   ('antifaterrorist', 1),
#   ('fweedom', 1),
#   ('uwzilgqdh', 1)],
#  [('stopthest', 1),
#   ('chao', 1),
#   ('mensen', 1),
#   ('bartschol', 1),
#   ('iemand', 1),
#   ('kunnen', 1),
#   ('leeft', 1),
#   ('liegen', 1),
#   ('ocharm', 1),
#   ('posten', 1),
#   ('pure', 1),
#   ('staalhard', 1),
#   ('vlaanderenbet', 1),
#   ('wauw', 1),
#   ('zien', 1),
#   ('zodat', 1)],
#  [('stopthest', 1),
#   ('vote', 1),
#   ('certifi', 1),
#   ('elector', 1),
#   ('italydidit', 1),
#   ('congress', 1),
#   ('colleg', 1),
#   ('httpstcokijhx', 1),
#   ('hurri', 1),
#   ('italianjob', 1),
#   ('pfow', 1),
#   ('stay', 1)],
#  [('stopthest', 1), ('antifaterrorist', 1), ('fweedom', 1)],
#  [('fight', 1),
#   ('stopthest', 1),
#   ('americafirst', 1),
#   ('love', 1),
#   ('presid', 1),
#   ('trump', 2),
#   ('trumpwon', 1),
#   ('continu', 1),
#   ('report', 1),
#   ('fakenew', 1),
#   ('california', 1),
#   ('despit', 1),
#   ('hker', 1)],
#  [('stopthest', 1),
#   ('video', 1),
#   ('american', 1),
#   ('cult', 1),
#   ('saccon', 1),
#   ('terror', 1),
#   ('terrorist', 1),
#   ('fawk', 1),
#   ('includ', 2),
#   ('cathol', 1),
#   ('domest', 1),
#   ('doug', 1),
#   ('gunpowd', 1),
#   ('mastriano', 1),
#   ('plot', 1),
#   ('prayer', 1),
#   ('rick', 1),
#   ('taliban', 1),
#   ('tradit', 1)],
#  [('stopthest', 1),
#   ('america', 1),
#   ('revolut', 1),
#   ('bupi', 1),
#   ('httpstcoxqw', 1),
#   ('princ', 1)],
#  [('stopthest', 1),
#   ('look', 1),
#   ('steal', 1),
#   ('like', 1),
#   ('absolut', 1),
#   ('america', 1),
#   ('republican', 1),
#   ('wrong', 1),
#   ('asshat', 1),
#   ('asshol', 1),
#   ('bunch', 1),
#   ('fuck', 3),
#   ('sissi', 1)],
#  [('fraud', 1),
#   ('stopthest', 1),
#   ('voter', 1),
#   ('elect', 1),
#   ('fair', 1),
#   ('disgust', 1),
#   ('jacindaardern', 1),
#   ('transpar', 1),
#   ('voterid', 1)],
#  [('stopthest', 1),
#   ('trumpwon', 1),
#   ('like', 1),
#   ('capitolriot', 1),
#   ('nazi', 1),
#   ('propaganda', 1),
#   ('charg', 1),
#   ('bidench', 1),
#   ('ashlibabbit', 1),
#   ('call', 1),
#   ('bernardkerik', 1),
#   ('colorrevolut', 1),
#   ('corruptmedia', 1),
#   ('httpstcolxz', 1),
#   ('reichstag', 1),
#   ('rinotraitor', 1)],
#  [('stopthest', 1),
#   ('httpstco', 1),
#   ('antifaterrorist', 1),
#   ('fweedom', 1),
#   ('dtrusb', 1)],
#  [('stopthest', 1),
#   ('antifa', 1),
#   ('riot', 2),
#   ('away', 1),
#   ('protest', 1),
#   ('peac', 1),
#   ('burn', 1),
#   ('year', 1),
#   ('assault', 1),
#   ('call', 2),
#   ('autonom', 1),
#   ('batteri', 1),
#   ('busi', 1),
#   ('citi', 1),
#   ('destroy', 1),
#   ('loot', 1),
#   ('set', 1),
#   ('standwithjohn', 1),
#   ('zone', 1)],
#  [('stopthest', 1), ('antifaterrorist', 1), ('fweedom', 1)],
#  [('stopthest', 1),
#   ('trump', 1),
#   ('capitol', 1),
#   ('conserv', 1),
#   ('breach', 1),
#   ('immedi', 1),
#   ('pelosislaptop', 1),
#   ('push', 1),
#   ('remov', 1),
#   ('retriev', 1),
#   ('silenc', 1)],
#  [('stopthest', 1),
#   ('wethepeopl', 1),
#   ('capitol', 1),
#   ('desper', 1),
#   ('chao', 1),
#   ('savetherepubl', 1),
#   ('need', 1),
#   ('answer', 1),
#   ('question', 1)],
#  [('stopthest', 1),
#   ('httpstco', 1),
#   ('antifaterrorist', 1),
#   ('fweedom', 1),
#   ('uin', 1)],
#  [('fraud', 1),
#   ('stopthest', 1),
#   ('presid', 1),
#   ('peopl', 1),
#   ('steal', 1),
#   ('elect', 1),
#   ('exact', 1),
#   ('democrat', 1),
#   ('happen', 1),
#   ('rememb', 1),
#   ('cheat', 1),
#   ('respons', 1),
#   ('dcriot', 1),
#   ('hadnt', 1),
#   ('mailfraud', 1),
#   ('place', 1),
#   ('wouldnt', 1)],
#  [('stopthest', 1),
#   ('presid', 1),
#   ('trump', 1),
#   ('know', 1),
#   ('amend', 1),
#   ('swamp', 1),
#   ('come', 1),
#   ('readi', 1),
#   ('what', 1),
#   ('lose', 1),
#   ('qanon', 1),
#   ('line', 1),
#   ('activ', 1),
#   ('hold', 1),
#   ('push', 1),
#   ('cabinet', 1),
#   ('cell', 1),
#   ('httpstcobcr', 1)],
#  [('stopthest', 1),
#   ('wethepeopl', 1),
#   ('fightback', 1),
#   ('draintheswamp', 1),
#   ('electionfraud', 1),
#   ('stopthefraud', 1),
#   ('dominion', 1)],
#  [('stopthest', 1),
#   ('that', 2),
#   ('your', 1),
#   ('like', 1),
#   ('hashtag', 1),
#   ('dear', 1),
#   ('congress', 1),
#   ('clean', 2),
#   ('dismiss', 1),
#   ('invad', 1),
#   ('serious', 1)],
#  [('hawleymo', 1),
#   ('stopthest', 1),
#   ('presid', 1),
#   ('trump', 2),
#   ('maga', 1),
#   ('tedcruz', 1),
#   ('potus', 1),
#   ('thank', 1),
#   ('realdonaldtrump', 1),
#   ('electionfraud', 1),
#   ('donald', 1),
#   ('drpaulgosar', 1),
#   ('erictrump', 1),
#   ('teamtrump', 1),
#   ('billspadea', 1),
#   ('donaldjtrumpjr', 1),
#   ('flotus', 1),
#   ('httpstcoamb', 1),
#   ('mattgaetz', 1),
#   ('stclairashley', 1)],
#  [('stopthest', 1),
#   ('democrat', 1),
#   ('version', 1),
#   ('uniti', 1),
#   ('stalin', 1)],
#  [('stopthest', 2), ('maga', 2), ('washington', 1), ('washingtondc', 1)],
#  [('stopthest', 1), ('antifa', 1), ('httpstcokninm', 1), ('httpstcoyam', 1)],
#  [('stopthest', 1),
#   ('american', 1),
#   ('support', 2),
#   ('million', 1),
#   ('call', 1),
#   ('place', 1),
#   ('ballot', 1),
#   ('congressmen', 2),
#   ('constitu', 1),
#   ('disenfranchis', 1),
#   ('expuls', 1),
#   ('punish', 1),
#   ('ten', 1)],
#  [('fight', 1), ('stopthest', 1), ('stand', 1), ('realdonaldtrump', 1)],
#  [('claim', 1),
#   ('stopthest', 1),
#   ('away', 1),
#   ('media', 1),
#   ('blame', 1),
#   ('realdonaldtrump', 1),
#   ('vote', 1),
#   ('certifi', 1),
#   ('constitut', 1),
#   ('contest', 1),
#   ('coup', 1),
#   ('elector', 1),
# ...
#   ('fdrlst', 1),
#   ('justicetristan', 1)],
#  [('stopthest', 1), ('httpstco', 1), ('yafqxd', 1)],
#  [('stopthest', 1),
#   ('democrat', 1),
#   ('twitter', 1),
#   ('realdonaldtrump', 1),
#   ('januari', 1),
#   ('account', 1),
#   ('standwithtrump', 1),
#   ('deactiv', 1),
#   ('indefinit', 1)],
#  [('stopthest', 1),
#   ('presid', 1),
#   ('get', 1),
#   ('happen', 1),
#   ('final', 1),
#   ('kill', 1),
#   ('action', 1),
#   ('weve', 1)],
#  [('stopthest', 1),
#   ('peopl', 1),
#   ('elect', 1),
#   ('believ', 1),
#   ('loser', 2),
#   ('fair', 1),
#   ('person', 1),
#   ('sore', 1),
#   ('weak', 1),
#   ('accept', 1),
#   ('spoil', 1)],
#  [('stopthest', 1),
#   ('word', 1),
#   ('trump', 3),
#   ('stopthesteai', 1),
#   ('potus', 1),
#   ('think', 1),
#   ('famili', 1),
#   ('danscavino', 1),
#   ('good', 1),
#   ('realdonaldtrump', 1),
#   ('father', 1),
#   ('wonder', 1),
#   ('ivankatrump', 1),
#   ('rest', 1),
#   ('tiffanyatrump', 1),
#   ('landslid', 1),
#   ('suppress', 1),
#   ('stopthech', 1)],
#  [('stopthest', 1),
#   ('turn', 1),
#   ('protrump', 1),
#   ('continu', 1),
#   ('republ', 1),
#   ('finish', 1),
#   ('listen', 1),
#   ('stopthestealus', 1),
#   ('self', 1),
#   ('promot', 1),
#   ('condescens', 1),
#   ('incess', 1),
#   ('mission', 1)],
#  [('stopthest', 1),
#   ('presid', 1),
#   ('unit', 1),
#   ('maga', 1),
#   ('steal', 1),
#   ('elect', 1),
#   ('state', 1),
#   ('capit', 1),
#   ('terrorist', 1),
#   ('insurrect', 1),
#   ('insid', 1),
#   ('chant', 1)],
#  [('stopthest', 1),
#   ('trump', 2),
#   ('maga', 1),
#   ('encourag', 1),
#   ('amend', 1),
#   ('capitol', 1),
#   ('riot', 1),
#   ('penc', 1),
#   ('attack', 1),
#   ('serv', 1),
#   ('capit', 1),
#   ('violenc', 1),
#   ('sedit', 1),
#   ('lie', 1),
#   ('invok', 1),
#   ('impeach', 1),
#   ('step', 1),
#   ('jail', 1),
#   ('bolder', 1),
#   ('unfit', 1)],
#  [('stopthest', 1),
#   ('say', 1),
#   ('event', 1),
#   ('evid', 1),
#   ('mountain', 1),
#   ('youtub', 1),
#   ('genflynn', 1),
#   ('innoc', 1),
#   ('blow', 1),
#   ('cancel', 1),
#   ('civilian', 1),
#   ('epicent', 1),
#   ('near', 1)],
#  [('stopthest', 1),
#   ('support', 1),
#   ('januari', 1),
#   ('flatearth', 1),
#   ('jaredkushn', 1),
#   ('americanistan', 1),
#   ('choic', 1),
#   ('fromag', 1),
#   ('httpstcotn', 1),
#   ('jesuss', 1),
#   ('lune', 1),
#   ('societi', 1),
#   ('vkcwj', 1)],
#  [('stopthest', 1),
#   ('trump', 2),
#   ('maga', 1),
#   ('antifa', 1),
#   ('like', 1),
#   ('media', 1),
#   ('support', 1),
#   ('news', 1),
#   ('group', 1),
#   ('stag', 1),
#   ('actor', 2),
#   ('fact', 1),
#   ('outrag', 1),
#   ('fli', 1),
#   ('cdnpoli', 1),
#   ('small', 1),
#   ('attract', 1),
#   ('discredit', 1),
#   ('horn', 1),
#   ('percent', 1),
#   ('tini', 1),
#   ('vinegar', 1)],
#  [('stopthest', 1),
#   ('trump', 1),
#   ('fightforamerica', 1),
#   ('elect', 1),
#   ('media', 1),
#   ('democraci', 1),
#   ('realdonaldtrump', 1),
#   ('hous', 1),
#   ('whitehous', 1),
#   ('rig', 1),
#   ('social', 1),
#   ('real', 1),
#   ('tosaveamerica', 1),
#   ('news', 1),
#   ('antifaterrorist', 1),
#   ('illeg', 1),
#   ('year', 1),
#   ('tri', 1),
#   ('remov', 1),
#   ('hire', 1),
#   ('thedemocrat', 1),
#   ('threat', 1),
#   ('sit', 1),
#   ('deathodemocraci', 1)],
#  [('stopthest', 1),
#   ('ignor', 1),
#   ('yesterday', 1),
#   ('happen', 1),
#   ('boss', 1),
#   ('instruct', 1),
#   ('insubordin', 1),
#   ('piousli', 1),
#   ('pontif', 1)],
#  [('stopthest', 1),
#   ('trump', 1),
#   ('capitolriot', 1),
#   ('need', 1),
#   ('nobelpeacepr', 1),
#   ('nomin', 1)],
#  [('stopthest', 1),
#   ('support', 1),
#   ('januari', 1),
#   ('flatearth', 1),
#   ('americanistan', 1),
#   ('choic', 1),
#   ('fromag', 1),
#   ('jesuss', 1),
#   ('lune', 1),
#   ('societi', 1),
#   ('httpstcomvfcd', 1)],
#  [('stopthest', 1),
#   ('support', 1),
#   ('januari', 1),
#   ('flatearth', 1),
#   ('americanistan', 1),
#   ('choic', 1),
#   ('fromag', 1),
#   ('jesuss', 1),
#   ('lune', 1),
#   ('societi', 1)],
#  [('stopthest', 1),
#   ('support', 1),
#   ('januari', 1),
#   ('flatearth', 1),
#   ('americanistan', 1),
#   ('choic', 1),
#   ('fromag', 1),
#   ('jesuss', 1),
#   ('lune', 1),
#   ('societi', 1),
#   ('cdiyvc', 1),
#   ('httpstcoijr', 1)],
#  [('stopthest', 1),
#   ('inform', 1),
#   ('tweet', 2),
#   ('identifi', 1),
#   ('httpstcoe', 1),
#   ('account', 1),
#   ('mention', 1),
#   ('inauthent', 1),
#   ('mbancdfc', 1)],
#  [('fight', 2),
#   ('stopthest', 1),
#   ('presid', 2),
#   ('stop', 1),
#   ('leav', 1),
#   ('like', 1),
#   ('support', 1),
#   ('realdonaldtrump', 1),
#   ('hang', 1),
#   ('disappoint', 1),
#   ('huge', 1),
#   ('keepfight', 1),
#   ('shawng', 1)],
#  [('stopthest', 1),
#   ('america', 1),
#   ('twitter', 1),
#   ('problem', 1),
#   ('voic', 1),
#   ('organ', 1),
#   ('freespeech', 1),
#   ('silenc', 1),
#   ('account', 1),
#   ('suspend', 1),
#   ('better', 1),
#   ('wors', 1),
#   ('firstamend', 1),
#   ('dissent', 1),
#   ('michaelcoudrey', 1)],
#  [('stopthest', 1),
#   ('peopl', 1),
#   ('antifa', 1),
#   ('patriot', 1),
#   ('know', 1),
#   ('right', 1),
#   ('yesterday', 1),
#   ('extrem', 1),
#   ('realdonaldtrump', 1),
#   ('ralli', 1),
#   ('violenc', 1),
#   ('real', 1),
#   ('attend', 1),
#   ('repres', 1),
#   ('wing', 1),
#   ('landslid', 1),
#   ('billfoxla', 1),
#   ('condon', 1),
#   ('freak', 1),
#   ('jodil', 1)],
#  [('statement', 1),
#   ('stopthest', 1),
#   ('maga', 1),
#   ('movement', 1),
#   ('dont', 1),
#   ('yesterday', 1),
#   ('like', 1),
#   ('conserv', 1),
#   ('hear', 1),
#   ('parti', 1),
#   ('base', 1),
#   ('repkinzing', 1),
#   ('opinion', 1),
#   ('ther', 1),
#   ('plant', 1),
#   ('badactor', 1),
#   ('career', 1),
#   ('chnage', 1)],
#  [('stopthest', 1),
#   ('fightback', 1),
#   ('fightfortrump', 1),
#   ('realdonaldtrump', 1),
#   ('congress', 1)],
#  [('stopthest', 2),
#   ('trump', 2),
#   ('good', 1),
#   ('youtub', 1),
#   ('speech', 1),
#   ('capitalhil', 1),
#   ('proudboy', 1),
#   ('proudboysusa', 1),
#   ('dude', 1),
#   ('httpstcom', 1),
#   ('bjgds', 1),
#   ('clip', 1),
#   ('gooddud', 1),
#   ('rubicon', 1),
#   ('trumpspeech', 1)],
#  [('stopthest', 1), ('trumpwon', 1), ('godwin', 1)],
#  [('stopthest', 1),
#   ('maga', 1),
#   ('traitor', 3),
#   ('coupattempt', 1),
#   ('forev', 1),
#   ('coup', 1),
#   ('rememb', 1),
#   ('attempt', 1),
#   ('ashlibabbit', 1),
#   ('die', 1),
#   ('arresttrumpnow', 1),
#   ('cwxa', 1),
#   ('httpstcovh', 1),
#   ('magacoup', 1),
#   ('magaterror', 1)],
#  [('stopthest', 1),
#   ('httpstco', 1),
#   ('capitolbuild', 1),
#   ('thousand', 1),
#   ('ruin', 1),
#   ('attaboy', 1),
#   ('awsht', 1),
#   ('dozen', 1),
#   ('wgzuo', 1)],
#  [('stopthest', 1),
#   ('capitol', 1),
#   ('riot', 1),
#   ('lawmak', 1),
#   ('problem', 1),
#   ('kelli', 1),
#   ('loser', 1),
#   ('plan', 1),
#   ('georgia', 1),
#   ('drop', 1),
#   ('rino', 1),
#   ('object', 1),
#   ('loeffler', 2),
#   ('turnout', 1),
#   ('chicken', 1),
#   ('dmdua', 1),
#   ('httpstcowwxu', 1),
#   ('runoff', 1),
#   ('testimoni', 1)],
#  [('stopthest', 1),
#   ('goplead', 1),
#   ('uphold', 1),
#   ('enforc', 1),
#   ('reppatfallon', 1)],
#  [('stopthest', 1),
#   ('trump', 1),
#   ('maga', 1),
#   ('evid', 1),
#   ('democraci', 1),
#   ('realdonaldtrump', 1),
#   ('inform', 1),
#   ('perfect', 1),
#   ('fakenew', 1),
#   ('place', 1),
#   ('spread', 1),
#   ('ruin', 1),
#   ('joebidench', 1),
#   ('pick', 1),
#   ('bias', 1),
#   ('demorat', 1)],
#  [('stopthest', 1),
#   ('kamalaharri', 1),
#   ('italydidit', 1),
#   ('speakerpelosi', 1),
#   ('lindseygrahamsc', 1),
#   ('senatemajldr', 1),
#   ('chuckschum', 1),
#   ('blueskyreport', 1),
#   ('dodgekim', 1),
#   ('httpstcolzpcj', 1),
#   ('jiebiden', 1),
#   ('nkfg', 1)],
#  [('go', 1),
#   ('stopthest', 1),
#   ('didnt', 1),
#   ('good', 1),
#   ('whos', 1),
#   ('histori', 1),
#   ('wrong', 1),
#   ('money', 1),
#   ('prison', 1),
#   ('donat', 1),
#   ('hope', 1),
#   ('sound', 1),
#   ('defend', 1),
#   ('luck', 1),
#   ('term', 1),
#   ('campaign', 1),
#   ('capntact', 1),
#   ('dopey', 1),
#   ('drrtmcgirt', 1),
#   ('gaxaz', 1),
#   ('httpstcotnrt', 1),
#   ('thehil', 1)],
#  [('stopthest', 1),
#   ('trump', 1),
#   ('maga', 1),
#   ('know', 1),
#   ('communist', 1),
#   ('right', 1),
#   ('leav', 1),
#   ('american', 1),
#   ('take', 1),
#   ('time', 1),
#   ('canada', 1),
#   ('control', 1),
#   ('parti', 1),
#   ('long', 1),
#   ('wing', 2),
#   ('decad', 1),
#   ('cdnpoli', 1),
#   ('belong', 1),
#   ('bird', 1),
#   ('technocraci', 1),
#   ('uniparti', 1)],
#  [('stopthest', 1),
#   ('traitor', 1),
#   ('holdthelin', 1),
#   ('proof', 1),
#   ('bless', 1),
#   ('take', 2),
#   ('watch', 1),
#   ('expos', 1),
#   ('httpstcoxnetxi', 1),
#   ('inargu', 1),
#   ('insuradud', 1),
#   ('keepthefaith', 1),
#   ('lebronsonroid', 1)],
#  [('stopthest', 1),
#   ('trump', 1),
#   ('wethepeopl', 1),
#   ('fightfortrump', 1),
#   ('censur', 1),
#   ('bigtech', 1),
#   ('censorship', 1),
#   ('libpol', 1),
#   ('sdrik', 1),
#   ('skpol', 1),
#   ('svpol', 1),
#   ('swebbtv', 1)],
#  [('stopthest', 1),
#   ('maga', 1),
#   ('steal', 1),
#   ('stormthecapit', 1),
#   ('attack', 1),
#   ('complet', 1),
#   ('updat', 1),
#   ('stag', 1),
#   ('falseflag', 1),
#   ('mikeadam', 1),
#   ('situat', 1),
#   ('votefraud', 1)],
#  [('stopthest', 1),
#   ('say', 1),
#   ('mean', 1),
#   ('beinggerr', 1),
#   ('pearlfromca', 1)],
#  [('stopthest', 1),
#   ('trump', 1),
#   ('maga', 1),
#   ('patriot', 1),
#   ('draintheswamp', 1),
#   ('polic', 1),
#   ('right', 1),
#   ('yesterday', 1),
#   ('beat', 1),
#   ('exercis', 1),
#   ('httpstcoylv', 1)],
#  [('stopthest', 1),
#   ('trump', 1),
#   ('maga', 1),
#   ('open', 1),
#   ('welcom', 1),
#   ('arm', 1),
#   ('expect', 1),
#   ('httpstcofhcyp', 1),
#   ('inhalethemac', 1),
#   ('trumpcoup', 1)],
#  [('stopthest', 1), ('maga', 1), ('shut', 1), ('hear', 1), ('nanhayworth', 1)],
#  [('stopthest', 1),
#   ('presid', 1),
#   ('trump', 1),
#   ('sure', 2),
#   ('come', 1),
#   ('globalist', 1),
#   ('plan', 1),
#   ('platform', 1),
#   ('master', 1),
#   ('year', 1),
#   ('need', 1),
#   ('certain', 1),
#   ('fine', 1),
#   ('board', 1),
#   ('fogcitymidg', 1),
#   ('trash', 1),
#   ('fuckerberg', 1),
#   ('surviv', 1),
#   ('yougotpunk', 1)],
#  [('stopthest', 1), ('maga', 1), ('patriot', 1), ('complet', 1)],
#  [('stopthest', 1),
#   ('maga', 1),
#   ('dont', 1),
#   ('america', 1),
#   ('tasheebell', 1),
#   ('realiz', 1),
#   ('case', 1),
#   ('wewaratwar', 1)],
#  [('stopthest', 1),
#   ('maga', 1),
#   ('steal', 1),
#   ('state', 1),
#   ('georgia', 1),
#   ('democrap', 1)],
#  [('stopthest', 1), ('realdonaldtrump', 1), ('vote', 1), ('phillip', 1)],
#  [('your', 1),
#   ('draintheswamp', 1),
#   ('work', 1),
#   ('republican', 1),
#   ('parti', 1),
#   ('ball', 1),
#   ('repkinzing', 1),
#   ('backbon', 1)],
#  [('stopthest', 1),
#   ('maga', 1),
#   ('potus', 1),
#   ('realdonaldtrump', 1),
#   ('conserv', 1),
#   ('asid', 1),
#   ('cheat', 1),
#   ('presssec', 1),
#   ('ingrahamangl', 1),
#   ('seanhann', 1),
#   ('tuckercarlson', 1),
#   ('liar', 1),
#   ('civilunrest', 1),
#   ('cruscifi', 1),
#   ('davidfab', 1),
#   ('justifi', 1),
#   ('leftw', 1),
#   ('libtard', 1)],
#  [('stopthest', 1),
#   ('capitol', 1),
#   ('penc', 1),
#   ('storm', 1),
#   ('lose', 1),
#   ('staff', 1),
#   ('open', 1),
#   ('youv', 1),
#   ('hurri', 1),
#   ('cultist', 1),
#   ('chief', 1),
#   ('chin', 1),
#   ('cotton', 1),
#   ('lindsey', 1)],
#  [('stopthest', 1),
#   ('love', 1),
#   ('fourmoreyear', 1),
#   ('annakhait', 1),
#   ('realmattcouch', 1),
#   ('iheartmindi', 1),
#   ('chrislipp', 1),
#   ('cindychafian', 1),
#   ('drcordiew', 1),
#   ('nicolenogradi', 1)],
#  [('stopthest', 1), ('maga', 1)],
#  [('stopthest', 1),
#   ('yesterday', 1),
#   ('believ', 1),
#   ('happen', 1),
#   ('insurrect', 1),
#   ('wild', 1)],
#  [('stopthest', 1),
#   ('notrumpnopeac', 1),
#   ('timetofight', 1),
#   ('wearecom', 1),
#   ('wearewatch', 1)],
#  [('stopthest', 1),
#   ('trump', 1),
#   ('danscavino', 1),
#   ('bnpzx', 1),
#   ('httpstcoumk', 1)],
#  [('stopthest', 1),
#   ('aaronjcarpent', 1),
#   ('pseudopresid', 1),
#   ('uselectionfraud', 1)],
#  [('stopthest', 1),
#   ('presid', 1),
#   ('know', 1),
#   ('think', 1),
#   ('support', 1),
#   ('plan', 1),
#   ('yougotpunk', 1)],
#  [('stopthest', 1),
#   ('maga', 1),
#   ('mean', 1),
#   ('juda', 1),
#   ('figur', 1),
#   ('aledagagarin', 1),
#   ('comm', 1),
#   ('darrigomelani', 1),
#   ('dog', 1),
#   ('judasp', 1),
#   ('voteashcraft', 1)],
#  [('stopthest', 1),
#   ('presid', 1),
#   ('trump', 3),
#   ('maga', 1),
#   ('patriot', 1),
#   ('sure', 1),
#   ('american', 1),
#   ('histori', 1),
#   ('succeed', 1),
#   ('genflynn', 1),
#   ('sidneypowel', 1),
#   ('restartlead', 1),
#   ('best', 1),
#   ('restartmiga', 1),
#   ('miga', 1),
#   ('barbararedg', 1),
#   ('flynnneil', 1),
#   ('gojackflynn', 1),
#   ('josephjflynn', 1),
#   ('lofli', 1),
#   ('realmflynnjr', 1)],
#  [('stopthest', 1),
#   ('trump', 2),
#   ('maga', 1),
#   ('patriot', 2),
#   ('america', 1),
#   ('bless', 2),
#   ('genflynn', 1),
#   ('sidneypowel', 1),
#   ('restartlead', 2),
#   ('restartmiga', 1),
#   ('miga', 1),
#   ('barbararedg', 1),
#   ('flynnneil', 1),
#   ('gojackflynn', 1),
#   ('josephjflynn', 1),
#   ('lofli', 1),
#   ('realmflynnjr', 1),
#   ('persia', 1),
#   ('restart', 1)],
#  [('stopthest', 1), ('trump', 1), ('maga', 1), ('antifa', 1), ('cdnpoli', 1)],
#  [('stopthest', 1),
#   ('rememb', 1),
#   ('primari', 1),
#   ('treason', 1),
#   ('action', 1),
#   ('midterm', 1),
#   ('cxie', 1),
#   ('httpstcobtain', 1)],
#  [('stopthest', 1),
#   ('capitol', 1),
#   ('watch', 1),
#   ('worth', 1),
#   ('tell', 1),
#   ('enter', 1),
#   ('stori', 1),
#   ('dvxhlva', 1),
#   ('exclus', 1),
#   ('httpstconh', 1),
#   ('lifesitenew', 1)],
#  [('stopthest', 1),
#   ('maga', 1),
#   ('ignor', 1),
#   ('media', 1),
#   ('conserv', 1),
#   ('excus', 1),
#   ('address', 1),
#   ('lose', 1),
#   ('true', 1),
#   ('fakenew', 1),
#   ('repres', 1),
#   ('cours', 1),
#   ('issu', 1),
#   ('legit', 1),
#   ('concern', 1),
#   ('interlop', 1)],
#  [('stopthest', 1),
#   ('ladi', 1),
#   ('patriot', 1),
#   ('tri', 1),
#   ('die', 1),
#   ('young', 1)],
#  [('stopthest', 1), ('trump', 1), ('maga', 1), ('antifa', 1), ('cdnpoli', 1)],
#  [('stopthest', 1),
#   ('maga', 1),
#   ('antifa', 1),
#   ('polic', 1),
#   ('right', 1),
#   ('thank', 1),
#   ('like', 1),
#   ('capitol', 1),
#   ('watch', 1),
#   ('offic', 1),
#   ('terror', 1),
#   ('coup', 1),
#   ('violenc', 1),
#   ('pelosi', 1),
#   ('caus', 1),
#   ('mattgaetz', 1),
#   ('livestream', 1),
#   ('analysi', 1),
#   ('bus', 1),
#   ('klan', 1),
#   ('klux', 1),
#   ('subscrib', 1)],
#  [('stopthest', 1),
#   ('itali', 1),
#   ('explain', 1),
#   ('affidavit', 1),
#   ('httpstcozxfj', 1),
#   ('idozq', 1),
#   ('rome', 1)],
#  [('play', 1),
#   ('stopthest', 1),
#   ('day', 1),
#   ('polit', 1),
#   ('need', 1),
#   ('rino', 1),
#   ('chang', 1),
#   ('realmattcouch', 1),
#   ('affili', 1),
#   ('nopenev', 1),
#   ('record', 1),
#   ('theyv', 1)],
#  [('stopthest', 1),
#   ('httpstco', 1),
#   ('polic', 1),
#   ('increas', 1),
#   ('protest', 1),
#   ('ralli', 1),
#   ('respons', 1),
#   ('rightw', 1),
#   ('face', 1),
#   ('demonstr', 1),
#   ('blmlink', 1),
#   ('capitolsieg', 1),
#   ('consist', 1),
#   ('leadup', 1),
#   ('lzigv', 1),
#   ('mute', 1),
#   ('number', 1),
#   ('surpass', 1)],
#  [('stopthest', 1),
#   ('citizen', 1),
#   ('lead', 1),
#   ('account', 1),
#   ('reject', 1),
#   ('borrow', 1),
#   ('dividend', 1),
#   ('dormant', 1),
#   ('nigerian', 1),
#   ('serapnigeria', 1),
#   ('unclaim', 1)],
#  [('stopthest', 1),
#   ('peac', 1),
#   ('sweet', 1),
#   ('forbid', 1),
#   ('almighti', 1),
#   ('buy', 1),
#   ('chain', 1),
#   ('patrickhenri', 1),
#   ('price', 1),
#   ('slaveri', 1)],
#  [('go', 1),
#   ('stopthest', 1),
#   ('leav', 1),
#   ('sudden', 1),
#   ('protest', 1),
#   ('violenc', 1),
#   ('shit', 1),
#   ('despit', 1),
#   ('arm', 1),
#   ('celeb', 1),
#   ('weird', 1)],
#  [('stopthest', 1),
#   ('presid', 1),
#   ('peopl', 1),
#   ('trump', 1),
#   ('elect', 1),
#   ('american', 1),
#   ('bless', 1),
#   ('take', 1),
#   ('fail', 1),
#   ('corrupt', 1),
#   ('expos', 1),
#   ('institut', 1),
#   ('congress', 1),
#   ('jimjordan', 1),
#   ('dccongress', 1),
#   ('seventi', 1)],
#  [('stopthest', 1), ('exact', 1), ('savetherepubl', 1), ('rhino', 1)],
#  [('stopthest', 1),
#   ('httpstco', 1),
#   ('worth', 1),
#   ('listen', 1),
#   ('wakeup', 1),
#   ('jbvjxrnm', 1)],
#  [('say', 1),
#   ('trump', 2),
#   ('dont', 1),
#   ('evid', 2),
#   ('democrat', 1),
#   ('idiot', 1),
#   ('ashlibabbitt', 1),
#   ('lawyer', 1),
#   ('tri', 1),
#   ('therightmelissa', 1),
#   ('march', 1),
#   ('case', 1),
#   ('present', 1),
#   ('band', 1),
#   ('clever', 1),
#   ('disappearbut', 1),
#   ('stopthestealand', 1),
#   ('truefbi', 1)],
#  [('stopthest', 1),
#   ('word', 1),
#   ('exact', 1),
#   ('fakenew', 1),
#   ('racist', 1),
#   ('interview', 1),
#   ('note', 1),
#   ('phrase', 1),
#   ('radicalleft', 1),
#   ('chant', 1),
#   ('lockherup', 1),
#   ('vanillaisi', 1)],
#  [('fight', 1),
#   ('stopthest', 1),
#   ('eagleedmartin', 1),
#   ('periscop', 1),
#   ('wynk', 1),
#   ('httpstco', 1),
#   ('stand', 1),
#   ('america', 2),
#   ('blame', 1),
#   ('bless', 1),
#   ('cult', 1),
#   ('grind', 1),
#   ('hate', 1),
#   ('morn', 1),
#   ('move', 1),
#   ('penc', 1),
#   ('recap', 1),
#   ('strength', 1),
#   ('transit', 1),
#   ('spite', 1)],
#  ...]

# %%
lda_model = gensim.models.LdaMulticore(bow_corpus, num_topics=34, chunksize=2000, id2word=id2word, passes=20, iterations=400, workers=2, eval_every=None)

# %%
# num_topics = 10
# chunksize = 2000
# passes = 20
# iterations = 400
# eval_every = None  # Don't evaluate model perplexity, takes too much time.

# # Make a index to word dictionary.
# temp = dictionary[0]  # This is only to "load" the dictionary.
# id2word = dictionary.id2token

# model = LdaModel(
#     corpus=corpus,
#     id2word=id2word,
#     chunksize=chunksize,
#     alpha='auto',
#     eta='auto',
#     iterations=iterations,
#     num_topics=num_topics,
#     passes=passes,
#     eval_every=eval_every
# )

# %% [markdown]
# #### View Topics

# %%
from pprint import pprint

# Print the Keyword in the topics
pprint(lda_model.print_topics())
doc_lda = lda_model[bow_corpus]
# Out:
# [(28,
#   '0.105*"news" + 0.039*"stopthest" + 0.030*"fakenew" + 0.026*"cover" + '
#   '0.021*"hard" + 0.017*"cbsnew" + 0.017*"senrickscott" + 0.012*"foxnew" + '
#   '0.012*"senmikele" + 0.011*"miss"'),
#  (2,
#   '0.332*"stopthest" + 0.101*"marchfortrump" + 0.059*"realdonaldtrump" + '
#   '0.053*"senatemajldr" + 0.032*"goplead" + 0.022*"senjohnthun" + '
#   '0.021*"johncornyn" + 0.018*"draintheswamp" + 0.017*"januari" + '
#   '0.015*"housegop"'),
#  (3,
#   '0.080*"stopthest" + 0.053*"trump" + 0.053*"wethepeopl" + 0.051*"washington" '
#   '+ 0.039*"ahead" + 0.037*"terrorist" + 0.035*"march" + 0.032*"domest" + '
#   '0.030*"presid" + 0.028*"antifa"'),
#  (33,
#   '0.036*"stopthest" + 0.030*"away" + 0.028*"savetherepubl" + '
#   '0.026*"communism" + 0.021*"team" + 0.021*"httpstcok" + 0.021*"win" + '
#   '0.017*"patriotsunit" + 0.015*"remov" + 0.014*"belov"'),
#  (21,
#   '0.077*"stopthest" + 0.028*"save" + 0.022*"offici" + 0.020*"httpstcow" + '
#   '0.018*"coverag" + 0.018*"peopl" + 0.016*"youtub" + 0.016*"america" + '
#   '0.015*"walkaway" + 0.015*"order"'),
#  (10,
#   '0.093*"stopthest" + 0.050*"freedom" + 0.029*"plaza" + 0.018*"maga" + '
#   '0.014*"trumpral" + 0.012*"httpstco" + 0.011*"patriot" + 0.010*"washington" '
#   '+ 0.010*"dcprotest" + 0.009*"trump"'),
#  (17,
#   '0.083*"stopthest" + 0.050*"fightback" + 0.042*"voterfraud" + '
#   '0.040*"holdthelin" + 0.036*"america" + 0.023*"maga" + 0.022*"rig" + '
#   '0.021*"elect" + 0.020*"corrupt" + 0.019*"donotcertifi"'),
#  (30,
#   '0.079*"stopthest" + 0.071*"stand" + 0.060*"realdonaldtrump" + 0.048*"mikep" '
#   '+ 0.048*"presid" + 0.046*"sentedcruz" + 0.040*"right" + 0.034*"vote" + '
#   '0.030*"elect" + 0.029*"count"'),
#  (26,
#   '0.075*"stopthest" + 0.074*"steal" + 0.073*"trumpwon" + 0.055*"tri" + '
#   '0.048*"world" + 0.046*"elect" + 0.043*"trump" + 0.041*"peopl" + '
#   '0.039*"stopthecoup" + 0.038*"american"'),
#  (18,
#   '0.108*"stopthest" + 0.044*"colleg" + 0.039*"conserv" + 0.033*"trend" + '
#   '0.032*"lindseygrahamsc" + 0.031*"histori" + 0.031*"realdonaldtrump" + '
#   '0.024*"reject" + 0.019*"elector" + 0.017*"hashtag"'),
#  (29,
#   '0.073*"stopthest" + 0.049*"parti" + 0.027*"trump" + 0.022*"republican" + '
#   '0.022*"video" + 0.019*"white" + 0.019*"hous" + 0.018*"wait" + '
#   '0.016*"better" + 0.014*"enemi"'),
#  (5,
#   '0.079*"tomorrow" + 0.067*"stopthest" + 0.061*"electionfraud" + '
#   '0.050*"realdonaldtrump" + 0.048*"support" + 0.048*"newsmax" + '
#   '0.044*"senategop" + 0.040*"oann" + 0.040*"housegop" + 0.035*"trumpwon"'),
#  (25,
#   '0.109*"elect" + 0.070*"stopthest" + 0.023*"fraud" + 0.022*"steal" + '
#   '0.021*"biden" + 0.018*"vote" + 0.018*"dont" + 0.015*"peopl" + '
#   '0.015*"fraudul" + 0.013*"stand"'),
#  (22,
#   '0.175*"trump" + 0.119*"stopthest" + 0.113*"maga" + 0.028*"presid" + '
#   '0.028*"support" + 0.027*"realdonaldtrump" + 0.014*"live" + 0.014*"donald" + '
#   '0.014*"httpstco" + 0.011*"tosaveamerica"'),
#  (13,
#   '0.078*"stopthest" + 0.072*"llinwood" + 0.056*"realdonaldtrump" + '
#   '0.055*"sidneypowel" + 0.037*"rudygiuliani" + 0.034*"genflynn" + '
#   '0.029*"erictrump" + 0.028*"donaldjtrumpjr" + 0.021*"codemonkeyz" + '
#   '0.020*"patrickbyrn"'),
#  (12,
#   '0.061*"stopthest" + 0.040*"antifa" + 0.029*"trump" + 0.026*"protest" + '
#   '0.021*"peac" + 0.019*"support" + 0.019*"maga" + 0.015*"violenc" + '
#   '0.014*"burn" + 0.013*"peopl"'),
#  (19,
#   '0.064*"stopthest" + 0.043*"hear" + 0.020*"covid" + 0.018*"evid" + '
#   '0.016*"isnt" + 0.014*"justic" + 0.013*"wonder" + 0.013*"direct" + '
#   '0.013*"fact" + 0.013*"court"'),
#  (31,
#   '0.073*"stopthest" + 0.041*"million" + 0.031*"trump" + 0.027*"ralli" + '
#   '0.022*"event" + 0.019*"join" + 0.019*"destroy" + 0.015*"epochtim" + '
#   '0.015*"moron" + 0.015*"march"'),
#  (20,
#   '0.048*"stopthest" + 0.032*"tedcruz" + 0.029*"jimjordan" + 0.027*"expect" + '
#   '0.026*"day" + 0.020*"realdonaldtrump" + 0.018*"stopthefraud" + '
#   '0.017*"seanhann" + 0.015*"hawleymo" + 0.014*"home"'),
#  (11,
#   '0.085*"vote" + 0.081*"stopthest" + 0.046*"georgia" + 0.037*"fraud" + '
#   '0.028*"voter" + 0.023*"ballot" + 0.023*"elect" + 0.021*"count" + '
#   '0.020*"realdonaldtrump" + 0.019*"machin"')]

# %%
# Compute Perplexity
print('\nPerplexity: ', lda_model.log_perplexity(bow_corpus))  # a measure of how good the model is. lower the better.

# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model, texts=processed_docs, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)
# Out:
# Perplexity:  -9.18733766863072
#
# Coherence Score:  0.41294984050522754

# %%
# Visualize the topics
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(lda_model, bow_corpus, id2word)
vis
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-c127beb7854f> in <module>
#       1 # Visualize the topics
#       2 pyLDAvis.enable_notebook()
# ----> 3 vis = pyLDAvis.gensim.prepare(lda_model, bow_corpus, id2word)
#       4 vis
#
# NameError: name 'lda_model' is not defined
