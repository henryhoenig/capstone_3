# %%
# For a very large figure (see figsize)
# Can blow it up and screenshot smaller elements

# %%
import networkx as nx 
import matplotlib.pyplot as plt 

fig = plt.figure(figsize=(40, 40)) 
G = nx.fast_gnp_random_graph(300, 0.02, seed=1337) 
nx.draw(G, node_size=30) 
plt.axis('equal') 
plt.show() 
fig.savefig('waka.svg')

# %%
https://towardsdatascience.com/customizing-networkx-graphs-f80b4e69bedf

# %%
## Setting node color 

fig, ax = plt.subplots(figsize=(15,8))

relationships = pd.DataFrame({'from': ['A', 'A', 'A'], 
                              'to':   ['B', 'C', 'D']})
 
G = nx.from_pandas_edgelist(relationships, 'from', 'to', create_using=nx.Graph())

# Set node_color
nx.draw(G, with_labels=True, node_color='red')

# %%
## Setting node size

nx.draw(G, with_labels=True, node_size=1000)

# %%
## Setting edge width

# Set edge width
nx.draw(G, with_labels=True, width=3)

# %% [markdown]
# newline characters “\n” are accepted in node titles and often increase readability. For example, the node for John Gleason is listed as “John\nGleason”

# %% [markdown]
# ![biggish_graph.png](attachment:ecb97442-f7b0-4ada-b431-918f027998be.png)

# %%
# Can draw a biggish graph like this above, with a big figsize, then zoom in 


nx.draw(G, with_labels=True, cmap=cmap, font_size=8, 
        font_weight="bold", width=0.75, edgecolors='gray')

plt.show()

# %%
print('test')
# Out:
# test

# %%
import plotly.graph_objects as go

import networkx as nx

G = nx.random_geometric_graph(200, 0.125)

# %%
pos = nx.fruchterman_reingold_layout(G) #fruchterman_reingold 

fig = go.Figure(G)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-206742e945a7> in <module>
#       1 pos = nx.fruchterman_reingold_layout(G) #fruchterman_reingold
#       2
# ----> 3 fig = go.Figure(G)
#
# ~/anaconda3/envs/pytorch_latest_p37/lib/python3.7/site-packages/plotly/graph_objs/_figure.py in __init__(self, data, layout, frames, skip_invalid, **kwargs)
#     594             is invalid AND skip_invalid is False
#     595         """
# --> 596         super(Figure, self).__init__(data, layout, frames, skip_invalid, **kwargs)
#     597
#     598     def add_area(
#
# ~/anaconda3/envs/pytorch_latest_p37/lib/python3.7/site-packages/plotly/basedatatypes.py in __init__(self, data, layout_plotly, frames, skip_invalid, **kwargs)
#     515         # ### Import traces ###
#     516         data = self._data_validator.validate_coerce(
# ...
